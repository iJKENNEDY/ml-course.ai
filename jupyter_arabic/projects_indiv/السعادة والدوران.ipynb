# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](mlcourse.ai) – دورة مفتوحة للتعلم الآلي
# ### <center> المؤلف: أندريه ريم، أندريه ريم
#
# ## <center> مشروع تحليل البيانات الفردية
# ### <center> السعادة اليومية ومعدل دوران الموظفين

# %% [markdown]
# **خطة البحث**
# [الجزء الأول. شرح مجموعة البيانات والمهمة](#part1)<br>
# [الجزء 2. التحليل الكامل للبيانات الأولية](#part2)<br>
# [الجزء 2.1. مخضض](#part2.1)<br>
# [الجزء 2.1.1. زبد. وصف مجموعة البيانات والميزات](#part2.1.1)<br>
# [الجزء 2.1.2. زبد. تحليل البيانات الاستكشافية، التحليل البصري للميزات](#part2.1.2)<br>
# [الجزء 2.1.3. زبد. الأنماط والرؤى وخصائص البيانات](#part2.1.3)<br>
# [الجزء 2.2. الأصوات](#part2.2)<br>
# [الجزء 2.2.1. الأصوات. وصف مجموعة البيانات والميزات](#part2.2.1)<br>
# [الجزء 2.2.2. الأصوات. تحليل البيانات الاستكشافية، التحليل البصري للميزات](#part2.2.2)<br>
# [الجزء 2.2.3. الأصوات. الأنماط والرؤى وخصائص البيانات](#part2.2.3)<br>
# [الجزء 2.3. تعليقات نظيفة مجهولة المصدر](#part2.3)<br>
# [الجزء 2.3.1. تعليقات نظيفة مجهولة المصدر. وصف مجموعة البيانات والميزات](#part2.3.1)<br>
# [الجزء 2.3.2. تعليقات نظيفة مجهولة المصدر. تحليل البيانات الاستكشافية، التحليل البصري للميزات](#part2.3.2)<br>
# [الجزء 2.3.3. تعليقات نظيفة مجهولة المصدر. الأنماط والرؤى وخصائص البيانات](#part2.3.3)<br>[الجزء 2.4. التفاعلات مع التعليقات](#part2.4)<br>
# [الجزء 2.4.1. التفاعلات مع التعليقات. وصف مجموعة البيانات والميزات](#part2.4.1)<br>
# [الجزء 2.4.2. التفاعلات مع التعليقات. تحليل البيانات الاستكشافية، التحليل البصري للميزات](#part2.4.2)<br>
# [الجزء 2.4.3. التفاعلات مع التعليقات. الأنماط والرؤى وخصائص البيانات](#part2.4.3)<br>
# [الجزء 2.5. موظف. جمع كل البيانات في مجموعة بيانات واحدة](#part2.5)<br>
# [الجزء 2.5.1. موظف. وصف مجموعة البيانات والميزات](#part2.5.1)<br>
# [الجزء 2.5.2. موظف. هندسة الميزات ووصفها](#part2.5.2)<br>
# [الجزء 2.5.3. موظف. تحليل البيانات الاستكشافية، التحليل البصري للميزات](#part2.5.3)<br>
# [الجزء 2.5.4. موظف. الأنماط والرؤى وخصائص البيانات](#part2.5.4)<br>
# [الجزء الثالث. التحليل البصري للميزات](#part3)<br>
# [الجزء الرابع. الأنماط والرؤى وخصائص البيانات](#part4)<br>
# [الجزء 5. المعالجة المسبقة للبيانات](#part5)<br>
# [الجزء السادس. هندسة الميزات ووصفها](#part6)<br>
# [الجزء 7. التحقق المتبادل وضبط المعلمات الفائقة](#part7)<br>
# [الجزء 8. منحنيات التحقق والتعلم](#part8)<br>
# [الجزء 9. التنبؤ بالعينات المحظورة والاختبارية](#part9)<br>
# [الجزء 10. نموذج التقييم مع وصف المقاييس](#part10)<br>
# [الجزء 11. الاستنتاجات](#part11)<br>

# %% [markdown]
# ### الجزء الأول. شرح مجموعة البيانات والمهمة<a id='part1'></a>

# %% [markdown]
# <p> يستخدم هذا المشروع مجموعة البيانات من الموقع <a href="@@KEEP_00000@@ target=__blank>Happyforce</a>. البيانات متاحة للعامة من خلال <a href="@@KEEP_00001@@ target=__blank>Kaggle Datasets</a>.</p><p> ينص وصف مجموعة البيانات في Kaggle على:</p>
# <blockquote cite="@@KEEP_00002@@> تتكون البيانات من أربعة جداول: الأصوات والتعليقات والتفاعلات والتغيير. تم الحصول على التصويت عندما فتح أحد الموظفين التطبيق وأجاب على السؤال: ما مدى سعادتك في العمل اليوم؟ للتصويت، يشير الموظف إلى شعوره من خلال لمس أحد الرموز الأربعة التي ظهرت على الشاشة. بعد أن يشير الموظف إلى مستوى سعادته، تظهر شاشة ثانية حيث يمكنه إدخال شرح نصي (عادة شكوى أو اقتراح أو تعليق)، هذا هو جدول التعليقات. من بين 4356 موظفًا، علق 2638 موظفًا مرة واحدة على الأقل. وأخيرًا، في شاشة ثالثة يستطيع الموظف رؤية تعليقات أقرانه وإبداء إعجابه بها أو عدم إعجابه بها، ويتم تخزين هذه البيانات في جدول التفاعلات. 3,516 موظفًا أبدوا إعجابهم أو عدم إعجابهم بتعليق واحد على الأقل من تعليقات أقرانهم. يحتوي جدول الإلغاء على وقت توقف الموظف عن العمل (استقال أو تم فصله).</blockquote>
# في هذا المشروع الفردي، سأقوم بتطوير نموذج للتنبؤ بفصل الموظف. ولهذا سأستخدم بيانات عن سعادة الموظفين في الشركة. <br>
# **المتغير المستهدف هو الحقول السلبية التي لا تزال موجودة في churn.csv**.
# <p>تتكون مجموعة البيانات من أربعة ملفات:</p>
# <ul>
#     <li>churn.csv</li>
#     <li>votes.csv</li>
#     <li>comments_clean_anonimized.csv</li>
#     <li>commentInteractions.csv</li>
# </ul>

# %% [markdown]
# **لدي 4 ملفات بيانات وللتوضيح سأقوم بإجراء جميع مراحل التحليل على كل ملف بالتسلسل. لاحقًا، سأجمع كل البيانات في ملف واحد وأقوم بتحليلها.**

# %% [markdown]
# ### الجزء الثاني. التحليل الكامل للبيانات الأولية<a id='part2'></a>

# %% [markdown]
# #### الجزء 2.1. Churn<a id='part2.1'></a>

# %% [markdown]
# ##### الجزء 2.1.1. زبد. وصف مجموعة البيانات والميزات<a id='part2.1.1'></a>

# %% [markdown]
# يحتوي الملف **churn.csv** على معلومات حول تاريخ آخر تفاعل للموظف مع التطبيق.
# - **الموظف**: معرف صحيح يحدد هوية الموظف داخل الشركة.
# - **companyAlias**: معرف التجزئة لشركة معينة.
# - **numVotes**: إجمالي عدد أصوات السعادة الصادرة عن المستخدم.
# - **تاريخ المشاركة الأخيرة**: تاريخ آخر تفاعل للمستخدم مع التطبيق.
# - **لا يزال موجودًا**: قيمة منطقية صحيحة إذا كان المستخدم لا يزال مسجلاً في التطبيق.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.simplefilter('ignore')
# from pylab import rcParams
# rcParams['figure.figsize'] = 15, 10

# %%
churn = pd.read_csv('data/indiv/churn.csv', parse_dates=[3], 
                    dtype={
                        'employee': np.int32, 'numVotes': np.int32, 'stillExists': np.bool
                    }
                   ).drop_duplicates()
churn.head()

# %%
churn.describe().T

# %%
churn.info()

# %% [markdown]
# ##### الجزء 2.1.2. زبد. تحليل البيانات الاستكشافية، التحليل البصري للميزات<a id='part2.1.2'></a>

# %%
churn.head()

# %% [markdown]
# في الجدول أعلاه، يمكننا أن نرى أن هناك موظفين بمعرفات سلبية. دعونا استكشاف هذا السؤال

# %%
churn[churn['employee'] < 0].head()

# %% [markdown]
# قد تلاحظ أن هؤلاء الموظفين لديهم 0 أصوات، على التوالي، ولا أستطيع استخدامها لمهمتي. كما أن هؤلاء الموظفين لديهم متغير هدف سلبي.

# %%
churn[churn['employee'] < 0][['numVotes', 'stillExists']].nunique()

# %% [markdown]
# نعم، بالفعل هؤلاء الموظفون لم يصوتوا وجميعهم لا يعملون. في رأيي، هذا أمر شاذ وسوف أقوم بحذف جميع المعلومات المتعلقة بالموظفين ذوي المعرف السلبي.

# %%
churn = churn[churn['employee'] > 0]

# %% [markdown]
# نحن لسنا بحاجة إلى موظفين بدون أصوات، تحقق مما إذا كان هناك مثل هذا وإزالة، إذا كان هناك.

# %%
churn[churn['numVotes'] == 0]

# %%
churn = churn[churn['numVotes'] > 0]

# %% [markdown]
# نعلم أيضًا من وصف مجموعة البيانات أن معرفات الموظفين فريدة داخل الشركة فقط. سنقوم الآن بتحليل الشركات، وباختصار، نقوم بتغيير التجزئة إلى أرقام.

# %%
companies = churn['companyAlias'].unique()
print('We have a %s companies' % len(companies))

# %%
companies_map = {company: i for i, company in enumerate(companies)}
churn['companyAlias'] = churn['companyAlias'].map(companies_map).astype('int')

# %% [markdown]
# لذلك، قمنا بإعادة ترميز الشركات. الآن يمكننا إنشاء معرفات فريدة للموظفين. دعونا نفعل ذلك.

# %%
churn['employee'] = churn['companyAlias'].astype(str)+"_"+churn['employee'].astype(str)

# %% [markdown]
# يمكننا الآن معرفة عدد الموظفين الفريدين المتبقين في مجموعة البيانات الخاصة بنا.

# %%
print('We have %s unique employees' % churn['employee'].nunique())

# %% [markdown]
# دعونا نتحقق مما إذا كان جميع موظفينا فريدين حقًا.

# %%
churn[churn['companyAlias'] == 10]['employee'].value_counts().head(10)

# %% [markdown]
# هنا نرى أنه يمكن تكرار الموظفين في جدول التدوير

# %%
churn[(churn['employee'] == '10_118')].sort_values('lastParticipationDate')

# %% [markdown]
# أعتقد أنه من الخطأ أن نبقى في الأحدث فقط

# %%
emp_ids = churn['employee'].value_counts().index
emp_count = churn['employee'].value_counts()
removing_emps_ids = []
for emp_id, count in zip(emp_ids, emp_count):
    if count > 1:
        removing_emps_ids.append(emp_id)

for emp_id in removing_emps_ids:
    churn.drop(
        index=churn[churn['employee'] == emp_id].sort_values('lastParticipationDate').index[:-1], 
        inplace=True
    )

# %%
churn[(churn['employee'] == '10_118')].sort_values('lastParticipationDate')

# %% [markdown]
# الآن كل شيء على ما يرام

# %%
churn.head()

# %% [markdown]
# دعونا نستكشف عدد الموظفين في الشركات

# %%
churn.groupby('companyAlias').size().sort_values(ascending=False).head(),\
churn.groupby('companyAlias').size().sort_values(ascending=True).head()

# %%
churn.groupby('companyAlias').size().sort_values(ascending=False).plot(kind='bar');

# %% [markdown]
# يمكن ملاحظة أن عدد الموظفين يتم توزيعه بشكل كبير من 585 إلى 2. دعونا نكتشف عدد الموظفين المتوسطين في الشركات.

# %%
print('Mean count of employees %.2f' % churn.groupby('companyAlias').size().mean())

# %% [markdown]
# دعونا نلقي نظرة على توزيع عدد الأصوات بين الموظفين.

# %%
churn['numVotes'].describe()

# %%
churn['numVotes'].hist(bins=20);

# %% [markdown]
# لاحظ أن 75 بالمائة من الموظفين حصلوا على أقل من 66 صوتًا. يتم توزيع عدد الأصوات بشكل كبير.
# دعونا نستكشف الأشخاص الذين حصلوا على أكبر عدد من الأصوات.

# %%
churn.sort_values('numVotes', ascending=False).head(10)

# %% [markdown]
# يمكنك أن ترى أنهم يعملون في شركة واحدة ولم يتم فصل معظمهم بعد، وقد تكون هذه ميزة جيدة.
# دعونا نرى شركات أخرى.

# %%
churn[churn['companyAlias'] != 10].sort_values('numVotes', ascending=False).head(10)

# %% [markdown]
# يمكننا أن نلاحظ تشتتًا كبيرًا: 404 في الشركة - 0، و740 في الشركة - 10. **وفي شركات أخرى، يعمل الأشخاص الذين لديهم عدد كبير من الأصوات**

# %% [markdown]
# حقل **lastParticipationDate** هو تاريخ آخر تصويت، فلنأخذه بعين الاعتبار

# %%
churn.groupby('lastParticipationDate').size().plot();

# %% [markdown]
# دعونا ننظر إلى نفس البيانات، ولكن مع نافذة انزلاق أسبوعية.

# %%
churn.groupby('lastParticipationDate').size().rolling(window=7).mean().plot();

# %%
churn[churn['lastParticipationDate'] > '2017-03-07 00:00:00'].groupby('lastParticipationDate').size().plot();

# %%
print('The first record date - ', churn['lastParticipationDate'].min())
print('The last record date - ', churn['lastParticipationDate'].max())
td = (churn['lastParticipationDate'].max() - churn['lastParticipationDate'].min())
print('We have data for %.2f years' % (td.days/365))

# %% [markdown]
# يمكننا أن نرى أن عدد الأصوات في النهاية يتزايد بقوة. قد يكون هذا بسبب تزايد شعبية التطبيق أو أي شيء آخر.

# %% [markdown]
# حسنًا، لنقم بإنشاء **سمة الهدف من StillExists**

# %%
churn['target'] = (-churn['stillExists']).astype('int')
churn.drop('stillExists', axis=1, inplace=True)

# %%
churn.head()

# %% [markdown]
# الارتباطات مع الميزات الأخرى.

# %%
churn['target'].value_counts()

# %% [markdown]
# ### يرجى ملاحظة أن المتغير المستهدف هو ما إذا كان الشخص لا يزال يعمل أم لا. 1 - الموظف لا يعمل 0 - الموظف يعمل .

# %%
churn['target'].hist();

# %% [markdown]
# دعونا نلقي نظرة على متوسط عدد الأصوات للفئات المختلفة.

# %%
churn.groupby('target')['numVotes'].mean().plot(kind='bar');

# %%
churn[churn['target'] == 0]['numVotes'].mean(), \
churn[churn['target'] == 1]['numVotes'].mean()

# %% [markdown]
# وكما نرى، لا يختلف الأمر كثيرًا في الفصول الدراسية، على الرغم من أنه تجدر الإشارة إلى أنه لا يزال أعلى بالنسبة لأولئك الذين يعملون

# %%
churn[churn['target'] == 1].hist('numVotes', bins=20);

# %%
churn[churn['target'] == 0].hist('numVotes', bins=20);

# %% [markdown]
# دعونا نلقي نظرة على نسبة الطبقات في الشركات

# %%
churn.groupby(['companyAlias', 'target'])['employee'].count().plot(kind='bar', figsize=(15, 10));

# %% [markdown]
# في رأيي، هذا رسم بياني **مثير للاهتمام جدًا**، وهنا يمكننا أن نلاحظ على الفور حقيقتين مثيرتين للاهتمام.
# أولاً، يوجد في الشركات الكبيرة عدد أكبر من الموظفين المتقاعدين. وبعد ذلك ننظر إلى علاقة السعادة بعدد الموظفين في الشركة.
# ثانيا، هناك شركات يعمل فيها جميع الموظفين.

# %%
churn.groupby('companyAlias')['numVotes'].mean().sort_values(ascending=False).plot(kind='bar', figsize=(15, 10));

# %% [markdown]
# ##### 2.1.3. زبد. الأنماط والرؤى وخصائص البيانات<a id='part2.1.3'></a>

# %% [markdown]
# وقد لاحظنا في هذه المجموعة من البيانات عدة ملاحظات هامة:
# 1. الموظفون الذين لديهم معرفات سلبية وأصوات صفر غير مناسبين لمهمتنا، حيث ليس لديهم أصوات.
# 2. لدينا شركات كبيرة (585 موظفًا) وشركات صغيرة (9 موظفين)، وبمساعدة الرسم التخطيطي، أثبتنا أن حجم المبيعات في الشركات الكبيرة أكبر.
# 3. هناك شركات يعمل فيها جميع الموظفين.
# 4. الفئة المطلوبة لديها عدد أقل من الأصوات.
# 5. يزداد عدد الأصوات مع مرور الوقت.
# 6. لا توجد فجوات في البيانات.

# %% [markdown]
# #### الجزء 2.2.Votes<a id='part2.2'></a>

# %% [markdown]
# ##### الجزء 2.2.1. الأصوات. وصف مجموعة البيانات والميزات<a id='part2.2.1'></a>

# %% [markdown]
# يتم تخزين البيانات المتعلقة بأصوات مستخدمي التطبيق في **votes.csv**. يحتوي هذا الملف على 4 أعمدة مختلفة:
# - **الموظف**: معرف صحيح يحدد هوية الموظف داخل الشركة.
# - **companyAlias**: معرف التجزئة لشركة معينة.
# - **voteDate**: سلسلة تمثل تاريخ إصدار صوت معين.
# - **التصويت**: القيمة الرقمية للتصويت المنبعث تتراوح من 1 إلى 4.

# %%
votes = pd.read_csv(
    'data/indiv/votes.csv',parse_dates=[2],
    dtype={
        'employee': np.int32, 'vote': np.int32
    }).drop_duplicates()
votes.head()

# %% [markdown]
# من الضروري إحضار معرفات الموظفين والشركات بشكل عام.

# %%
votes = votes[votes['employee'] > 0]
votes['companyAlias'] = votes['companyAlias'].map(companies_map).astype('int')
votes['employee'] = votes['companyAlias'].astype(str)+"_"+votes['employee'].astype(str)

# %%
votes.head()

# %%
votes.describe().T

# %%
votes.info()

# %% [markdown]
# دعونا نرى ما هو عدد الأصوات موظفي الشركات

# %%
print(votes['companyAlias'].value_counts().head());

# %% [markdown]
# ##### الجزء 2.2.2. الأصوات. تحليل البيانات الاستكشافية، التحليل البصري للميزات<a id='part2.2.2'></a>

# %% [markdown]
# انظروا إلى توزيع الأصوات

# %%
votes.groupby('vote').size().plot(kind='bar');

# %% [markdown]
# نرى أن معظم الأشخاص **يكاد يكونون سعداء** في شركاتهم.<br>
# ومن المثير للاهتمام أن ننظر إلى توزيع الأصوات لفترات زمنية مختلفة، إضافة بضع ميزات.

# %%
votes['day_of_week'] = votes['voteDate'].dt.dayofweek
votes['month'] = votes['voteDate'].dt.month
votes['year'] = votes['voteDate'].dt.year

# %% [markdown]
# كم من الوقت لدينا احصائيات الأصوات؟

# %%
print(votes['voteDate'].min(), votes['voteDate'].max())

# %% [markdown]
# في هذه الفترة لدينا أصوات - **2014.06 - 2017.03**.

# %%
votes.groupby('voteDate').size().plot();

# %% [markdown]
# في هذا الرسم البياني، نحن مقتنعون بفرضية أن شعبية التطبيق آخذة في الازدياد.<br>
# دعونا ننظر إلى نفس الرسم البياني ولكن مع نافذة منزلقة.

# %%
votes.groupby('voteDate').size().rolling(window=31).mean().plot();

# %% [markdown]
# دعونا نحاول بناء جدول زمني لعدة أشهر.

# %%
votes.groupby('month').size().plot();

# %%
votes.groupby(['month', 'vote']).size().plot(kind='bar');

# %% [markdown]
# وكما نرى فإن الجدول الزمني مشابه جدًا للعام الماضي، لأن العام الماضي شهد أكبر زيادة في الجمهور.<br>
# بناء جدول لأيام الأسبوع.

# %%
votes.groupby(['day_of_week', 'vote']).size().plot(kind='bar');

# %% [markdown]
# بشكل عام، يعكس كل يوم الإعداد ككل، ولكن يمكنك أن ترى أن المزيد من الأشخاص وضعوا يوم الجمعة 4، مما يعني أنهم أكثر سعادة قبل عطلة نهاية الأسبوع. وبعض الأشخاص الغريبين يصوتون في عطلات نهاية الأسبوع ويكون معدل تصويتهم 1 أعلى من المعتاد.

# %% [markdown]
# انظر إلى توزيع الأصوات حسب السنة.

# %%
votes.groupby('year').size().plot(kind='bar');

# %%
votes.groupby(['year', 'vote']).size().plot(kind='bar');

# %% [markdown]
# ينمو التطبيق بنشاط كبير، يمكننا أن نرى أنه في 3 أشهر فقط من عام 2017، حصل التطبيق بالفعل على حوالي نصف الأصوات في عام 2016.

# %% [markdown]
# دعونا نرى كيف يصوت الموظفون في المتوسط

# %%
votes.groupby('employee')['vote'].mean().sort_values().plot();

# %% [markdown]
# وأتساءل كيف متوسط التصويت في الشركة.

# %%
votes.groupby('companyAlias')['vote'].mean().sort_values().plot(kind='bar', figsize=(12, 8));

# %%
plt.scatter(x=votes.groupby('companyAlias')['vote'].mean(), y=churn.groupby('companyAlias')['employee'].size());
plt.ylabel('Employees count')
plt.xlabel('Mean employees happiness')
plt.show()

# %% [markdown]
# في هذا الرسم البياني، نرى **علاقة مهمة بين سعادة الموظف وحجم الشركة**؛ كلما زاد عدد الموظفين، قل سعادة الموظف.

# %% [markdown]
# ارسم متوسط مستوى الاضطراب والسعادة للشركة

# %%
plt.scatter(x=votes.groupby('companyAlias')['vote'].mean(), y=churn.groupby('companyAlias')['target'].mean());
plt.xlabel('Mean employees happiness')
plt.ylabel('Mean churn')
plt.show()

# %% [markdown]
# يبدو بشكل حدسي أن الأشخاص غير السعداء ينسحبون في كثير من الأحيان، ولكن لا يوجد اعتماد صارم

# %% [markdown]
# ##### 2.2.3. الأصوات. الأنماط والرؤى وخصائص البيانات<a id='part2.2.3'></a>

# %% [markdown]
# وقد لاحظنا في هذه المجموعة من البيانات عدة ملاحظات هامة:
# 1. البيانات المجمعة للفترة 2014.06 - 2017.03.
# 2. التطبيق ينمو بنشاط كبير
# 3. غالبًا ما يكون الناس سعداء في شركاتهم ويختارون 3.
# 4. في يوم الجمعة، وضع عدد أكبر من الأشخاص 4.
# 5. العلاقة بين سعادة الموظف وحجم الشركة علاقة سلبية.
# 6. لا توجد فجوات في البيانات.

# %% [markdown]
# #### الجزء 2.3. تعليقات نظيفة مجهولة المصدر<a id='part2.3'></a>

# %% [markdown]
# ##### الجزء 2.3.1. تعليقات نظيفة مجهولة المصدر. وصف مجموعة البيانات والميزات<a id='part2.3.1'></a>

# %% [markdown]
# من الممكن العثور على بيانات حول التعليقات المكتوبة في التطبيق في ملف **comments_clean_anonimized.csv**، وله البنية التالية:
# - **الموظف**: معرف صحيح يحدد هوية الموظف داخل الشركة.
# - **companyAlias**: معرف التجزئة لشركة معينة.
# - **commentDate**: سلسلة تمثل تاريخ كتابة تعليق معين.
# - **commentId**: معرف فريد لتعليق معين.
# - **تعليق**: تعليق مجهول المصدر. له نفس طول التعليق الأصلي.
# - **الإعجابات**: عدد الإعجابات التي تلقاها التعليق.
# - **عدم الإعجاب**: عدد مرات عدم الإعجاب التي تلقاها التعليق.

# %%
comments = pd.read_csv(
    'data/indiv/comments_clean_anonimized.csv', parse_dates=[-1],
    dtype={
        'employee': np.int32, 'likes': np.float, 'dislikes': np.float
    }).drop_duplicates()
comments.head()

# %%
comments.describe()

# %%
comments.info()

# %%
comments['txt'].fillna('', inplace=True)

# %% [markdown]
# من الضروري إحضار معرفات الموظفين والشركات بشكل عام.

# %%
comments = comments[comments['employee'] > 0]
comments['companyAlias'] = comments['companyAlias'].map(companies_map).astype('int')
comments['employee'] = comments['companyAlias'].astype(str)+"_"+comments['employee'].astype(str)

# %%
comments.head()

# %% [markdown]
# يمكننا أن نلاحظ أن نص التعليق مشفر، لكن يمكننا استخدامه، يمكننا أن نأخذ طوله وننشئ إشارة إلى وجود النص. <br>
# وإضافة بعض الميزات المتعلقة بالوقت

# %%
def get_len(txt):
    if type(txt) == str:
        return len(txt)
    else:
        return 0
        
def text_exist(txt):
    if type(txt) == str and len(txt) > 0:
        return 1
    else:
        return 0
        
comments['txt_len'] = comments['txt'].apply(get_len)
comments['txt_exist'] = comments['txt'].apply(text_exist)

comments['day_of_week'] = comments['commentDate'].dt.dayofweek
comments['month'] = comments['commentDate'].dt.month
comments['year'] = comments['commentDate'].dt.year

comments.drop(columns=['txt'], axis=1, inplace=True)

# %%
comments.dropna(inplace=True)

# %%
comments['likes'] = comments['likes'].astype('int64')
comments['dislikes'] = comments['dislikes'].astype('int64')

# %%
comments.head()

# %% [markdown]
# ##### الجزء 2.3.2. تعليقات نظيفة مجهولة المصدر. تحليل البيانات الاستكشافية، التحليل البصري للميزات<a id='part2.3.2'></a>

# %% [markdown]
# دعونا نرى كيف يتم توزيع التعليقات حسب الوقت.

# %%
comments.groupby('commentDate').size().plot(figsize=(12, 8));

# %% [markdown]
# هذا عادةً ما يكون تعليقًا واحدًا أو تعليقين. هنا لا نرى نموًا للتعليقات بمرور الوقت، ولكن هناك نوعًا من الارتفاع، يمكنك استكشافه.

# %%
comments[(comments['commentDate'] > '2016-09-01') & (comments['commentDate'] < '2016-10-01')].groupby('employee').size().sort_values(ascending=False).head()

# %%
comments[
    (comments['commentDate'] > '2016-09-01') & 
    (comments['commentDate'] < '2016-10-01') &
    (comments['employee'] == '22_278')
]

# %% [markdown]
# في الواقع، يقوم الموظف بكتابة رسائل بأطوال مختلفة، وإذا حكمنا من خلال الإعجابات، فإن زملائه يحبونها.<br>
# دعونا نرى، هل ما زال يعمل؟

# %%
churn[churn['employee'] == '22_278']

# %% [markdown]
# نعم، هذا الموظف لا يزال يعمل. أفترض أن **وجود النص وطوله** من الميزات الجيدة

# %% [markdown]
# كم عدد التعليقات التي يمكن كتابتها يوميا؟

# %%
comments.groupby(['commentDate', 'employee']).size().max()

# %% [markdown]
# دعونا نلقي نظرة على اثنين من الرسوم البيانية مع الإعجابات وعدم الإعجاب.

# %%
sns.boxplot(x='month', y='likes', data=comments);

# %%
sns.boxplot(x='month', y='dislikes', data=comments);

# %%
sns.boxplot(x='day_of_week', y='likes', data=comments);

# %% [markdown]
# ومن المثير للاهتمام أنه لا يوجد الكثير من الأصوات في عطلات نهاية الأسبوع، ولكن التعليقات المكتوبة في عطلات نهاية الأسبوع تجمع الكثير من الإعجابات، كما هو موضح في الرسم البياني أعلاه.

# %%
comments['likes'].hist(bins=20);

# %%
comments['dislikes'].hist(bins=20);

# %% [markdown]
# دعونا نتحقق من العلاقة بين طول النص وعدد الإعجابات.

# %%
plt.scatter(x=comments['txt_len'], y=comments['likes'])
# plt.label(label='Correlation bitween length of text and likes')
plt.xlabel('Lenght of text')
plt.ylabel('Number of likes')
plt.show()

# %% [markdown]
# لا يمكننا تفسير الرسم البياني بسبب النص الذي يبلغ طوله 30 كيلو بايت. دعونا إصلاحه.

# %%
plt.scatter(x=comments[comments['txt_len'] < 3000]['txt_len'], y=comments[comments['txt_len'] < 3000]['likes'])
plt.xlabel('Lenght of text')
plt.ylabel('Number of likes')
plt.show()

# %% [markdown]
# لا توجد علاقة واضحة. يمكن أن يحصل عدد كبير من الإعجابات على تعليقات قصيرة وأخرى طويلة قليلاً.

# %%
comments.info()

# %% [markdown]
# يوجد سجل واحد قذر، أعرف ما هو هذا السجل، وهو الأخير في مجموعة البيانات هذه

# %%
comments[-1:]

# %% [markdown]
# ربما، عند تنزيل البيانات من التطبيق، ظهر.

# %%
comments.dropna(inplace=True)

# %% [markdown]
# وأخيرا، فإننا ننظر إلى الارتباط بين الميزات

# %%
sns.heatmap(comments.corr());

# %% [markdown]
# يتم تسليط الضوء على اعتماد الإعجابات وطول النص.

# %% [markdown]
# ##### 2.3.3.  تعليقات نظيفة مجهولة المصدر. الأنماط والرؤى وخصائص البيانات<a id='part2.3.3'></a>

# %% [markdown]
# وقد لاحظنا في هذه المجموعة من البيانات عدة ملاحظات هامة:1. هناك نص طويل جدًا.
# 2. هناك علاقة طفيفة بين الإعجابات والنص الطويل.
# 3. لا يوجد أشخاص في البيانات يكتبون أكثر من تعليقين يوميًا.
# 4. التعليقات المكتوبة في عطلة نهاية الأسبوع، تجمع المزيد من الإعجابات.
# 5. لا توجد فجوات في البيانات.

# %% [markdown]
# #### الجزء 2.4. التفاعلات مع التعليقات<a id='part2.4'></a>

# %% [markdown]
# ##### الجزء 2.4.1.  التفاعلات مع التعليقات. وصف مجموعة البيانات والميزات<a id='part2.4.1'></a>

# %% [markdown]
# يحتوي الملف **commentInteractions.csv** على معلومات حول الموظف الذي أبدى إعجابه أو عدم إعجابه بتعليق معين.
# - **الموظف**: معرف صحيح يحدد هوية الموظف داخل الشركة.
# - **companyAlias**: معرف التجزئة لشركة معينة.
# - **commentId**: معرف فريد لتعليق معين يسمح لنا بربطه بالتعليقات الموجودة في anon_comments.csv.
# - **أعجبني**: قيمة منطقية صحيحة إذا أعجب الموظف بالتعليق.
# - **لم يعجبني**: قيمة منطقية صحيحة إذا لم يعجب الموظف بالتعليق.

# %%
comments_inters = pd.read_csv('data/indiv/commentInteractions.csv',
                              dtype={
                                  'employee': np.int32, 
                                  'liked': np.int32, 
                                  'disliked': np.int32
                              }).drop_duplicates().dropna()
comments_inters.head()

# %%
comments_inters.info()

# %%
comments_inters['companyAlias'] = comments_inters['companyAlias'].map(companies_map).astype('int')
comments_inters = comments_inters[comments_inters['employee'] >= 0]

# %% [markdown]
# إنشاء معرفات فريدة للموظفين<p>

# %%
comments_inters['employee'] = comments_inters['companyAlias'].astype(str)+"_"+comments_inters['employee'].astype(str)

# %%
comments_inters.head()

# %% [markdown]
# كم عدد الإعجابات وعدم الإعجاب من قبل الشركات

# %%
comments_inters['companyAlias'].value_counts().head()

# %% [markdown]
# توزيع **الإعجابات** حسب الشركة

# %% [markdown]
# يمكن لموظف سجل واحد أن يحب أو لا يعجبه، ولكن ليس معًا

# %%
len(comments_inters[
    (comments_inters['liked'] == False) & (comments_inters['disliked'] == False)
])

# %% [markdown]
# ##### الجزء 2.4.2. التفاعلات مع التعليقات. تحليل البيانات الاستكشافية، التحليل البصري للميزات<a id='part2.4.2'></a>

# %%
comments_inters[comments_inters['liked'] == True].groupby('companyAlias').size().sort_values().plot(kind='bar');

# %% [markdown]
# توزيع **الإعجابات** حسب الشركة

# %%
comments_inters[comments_inters['liked'] == False].groupby('companyAlias').size().sort_values().plot(kind='bar');

# %% [markdown]
# في الشركات الكبيرة من المتوقع أن يحبها الآخرون ويكرهونها

# %% [markdown]
# انظر إلى عدد الموظفين في الشركة وعدد الإعجابات وعدم الإعجاب لكل موظف

# %%
churn.groupby('companyAlias')['employee'].size().sort_values().plot(kind='bar');

# %% [markdown]
# المفتاح - التفاعلات لكل موظف، القيمة - عدد الموظفين

# %%
dict(zip((comments_inters.groupby('companyAlias').size() // churn.groupby('companyAlias').size()), churn.groupby('companyAlias').size()))

# %% [markdown]
# قد نلاحظ أن الشركات الصغيرة جدًا ليس لديها سجلات

# %%
plt.scatter(
    x=comments_inters.groupby('companyAlias').size() // churn.groupby('companyAlias').size(), 
    y=churn.groupby('companyAlias').size()
)
plt.title('Interactions per employee and number employees in company')
plt.xlabel('likes and dislikes per employee')
plt.ylabel('number employees in company')
plt.show()

# %% [markdown]
# دعونا نرى مدى قدرة الموظف على القيام بالتفاعلات

# %%
comments_inters.groupby('employee').size().sort_values(ascending=False).head(50).plot(kind='bar');

# %%
comments_inters.groupby('employee').size().mean()

# %% [markdown]
# هناك افتراض بأنه كلما كان الموظف أكثر نشاطا، كلما زادت احتمالية عمله. دعونا نرى ما إذا كان هؤلاء الموظفين يعملون حتى الآن.

# %%
so_active_employees = comments_inters.groupby('employee').size().sort_values(ascending=False).keys()[:20]
churn[churn['employee'].isin(so_active_employees)]

# %% [markdown]
# في الواقع، لا يزال جميع الموظفين تقريبًا يعملون.

# %% [markdown]
# ##### 2.4.3.  التفاعلات مع التعليقات. الأنماط والرؤى وخصائص البيانات<a id='part2.4.3'></a>

# %% [markdown]
# وقد لاحظنا في هذه المجموعة من البيانات عدة ملاحظات هامة:
# 1. هناك شركات قام فيها الموظفون بـ 200 تفاعل لكل موظف.
# 2. في المتوسط، أجرى الموظفون 109 تفاعلات
# 3. هناك موظفون قاموا بـ 3500 تفاعل.
# 4. توجد علاقة ارتباطية بين نشاط الموظف وعمله.
# 5. لا توجد فجوات في البيانات.

# %% [markdown]
# #### الجزء 2.5. موظف. جمع كافة البيانات في مجموعة بيانات واحدة<a id='part2.5'></a>

# %% [markdown]
# ##### الجزء 2.5.1. موظف. وصف مجموعة البيانات والميزات<a id='part2.5.1'></a>

# %% [markdown]
# اسمحوا لي أن أذكرك أننا نخطط للتنبؤ بخروج الموظفين. <br>
# للقيام بذلك، نحتاج إلى تجميع البيانات لكل موظف وإضافتها إلى مجموعة واحدة من البيانات.<br>
# بدت العلامات التالية مثيرة للاهتمام بالنسبة لي:
# 1. الأصوات (الحد الأدنى، الحد الأقصى، المتوسط، المعياري)
# 2. طول التعليقات ووجودها (الحد الأقصى، المتوسط، المعياري، المجموع)
# 3. رد الفعل على تعليقات الموظفين الآخرين (الإعجابات، عدم الإعجاب) (الحد الأدنى، الحد الأقصى، المتوسط، المعياري)
# 4. رد الفعل على تعليقات الموظفين (الإعجابات، عدم الإعجاب) (الحد الأدنى، الحد الأقصى، المتوسط، المعياري)
# 5. متوسط مستوى السعادة في الشركة
# 6. عدد الأشخاص في الشركة
# 7. عدد الأيام بين التصويت الأول والأخير

# %% [markdown]
# **'الموظف'** - المعرف الفريد للموظف<br>
# **'companyAlias'** - معرف الشركة الفريد<br>
# **'numVotes'** - عدد الأصوات التي تم تمريرها<br>
# **'target'** - هو المتغير المستهدف. لا يزال يعمل - 0، لا يعمل - 1<br>
# **('تصويت'، 'يعني')** - متوسط تصويت الموظف<br>
# **('تصويت'، 'دقيقة')** - الحد الأدنى لتصويت الموظف<br>
# **('تصويت'، 'حد أقصى')** - الحد الأقصى لتصويت الموظف<br>
# **('dislikes', 'mean')** - متوسط عدد مرات عدم الإعجاب المتلقاة للتعليقات من الزملاء<br>
# **('dislikes', 'sum')** - إجمالي عدد عدم الإعجابات المستلمة للتعليقات من الزملاء<br>
# **('dislikes', 'min')** - الحد الأدنى لعدد عدم الإعجابات المتلقاة للتعليقات من الزملاء<br>
# **('dislikes', 'max')** - الحد الأقصى لعدد عدم الإعجابات المتلقاة للتعليقات من الزملاء<br>
# **('الإعجابات'، 'المعنى')** - متوسط عدد الإعجابات المتلقاة للتعليقات من الزملاء<br>
# **('الإعجابات'، 'sum')** - إجمالي عدد الإعجابات التي تم تلقيها على تعليقاتهم من الزملاء<br>
# **('الإعجابات', 'الحد الأدنى')** - الحد الأدنى لعدد الإعجابات المتلقاة للتعليقات من الزملاء<br>
# **('الإعجابات'، 'الحد الأقصى')** - الحد الأقصى لعدد الإعجابات المتلقاة للتعليقات من الزملاء<br>
# **('txt_len', 'mean')** - متوسط طول نص التعليق<br>
# **('txt_len', 'sum')** - الطول الإجمالي لنصوص التعليقات<br>
# **('txt_len', 'min')** - الحد الأدنى لطول نص التعليق<br>
# **('txt_len', 'max')** - الحد الأقصى لطول نص التعليق<br>
# **('txt_exist', 'mean')** - نسبة الأصوات التي تحتوي على تعليق<br>**('لم يعجبني'، 'يعني')** - نسبة عدم الإعجاب من جميع التفاعلات مع الزملاء comments<br>
# **('dislike', 'sum')** - إجمالي عدد مرات عدم الإعجاب التي وضعها الموظف<br>
# **('أعجبني'، 'يعني')** - نسبة الإعجابات من جميع التفاعلات مع الزملاء comments<br>
# **('أعجبني'، 'sum')** - إجمالي عدد الإعجابات التي وضعها الموظف<br>
# **'mean_vote_by_company'** - يعني سعادة الموظفين في الشركة<br>
# **'num_emploees_by_company'** - عدد الموظفين في الشركة<br>
# **'first_last_vote_days'** - عدد الأيام بين التصويت الأول والأخير<br>

# %% [markdown]
# ##### الجزء 2.5.2. موظف. هندسة الميزات ووصفها <a id='part2.5.2'></a>

# %%
employee = pd.DataFrame()
employee = churn[['employee', 'companyAlias', 'numVotes', 'target']]

# %%
agg_votes = votes[['employee', 'vote']].groupby('employee', as_index=False).agg({'vote': [np.mean, min, max]})

agg_comments = comments[['employee', 'txt_len', 'likes', 'dislikes', 'txt_exist']]\
    .groupby('employee', as_index=False).agg(
        {
            'txt_len': [np.mean, np.sum, min, max],
            'likes': [np.mean, np.sum, min, max],
            'dislikes': [np.mean, np.sum, min, max],
            'txt_exist': [np.mean]
        }
    )

agg_employee_likes_dislokes = comments_inters[['employee', 'liked', 'disliked']].groupby('employee', as_index=False).agg(
    {
        'liked': [np.mean, np.sum],
        'disliked': [np.mean, np.sum],
    }
)

agg_work_long = votes[['employee', 'voteDate']].groupby('employee', as_index=False).agg({'voteDate': [min, max]})

employee = employee.merge(agg_votes, on=['employee','employee'],how='left')
employee = employee.merge(agg_comments, on=['employee','employee'],how='left')
employee = employee.merge(agg_employee_likes_dislokes, on=['employee','employee'],how='left')
employee = employee.merge(agg_work_long, on=['employee','employee'],how='left')

employee['first_last_vote_days'] = (employee[('voteDate', 'max')] - employee[('voteDate', 'min')]).dt.days
employee.drop([('voteDate', 'max'), ('voteDate', 'min')], axis=1, inplace=True)

employee.head()

# %%
mean_vote_by_company = votes.groupby('companyAlias')['vote'].mean().to_dict()
employee['mean_vote_by_company'] = employee['companyAlias'].map(mean_vote_by_company)

# %%
emploies_by_company = churn.groupby('companyAlias')['employee'].count().to_dict()
employee['num_emploees_by_company'] = employee['companyAlias'].map(emploies_by_company)

# %%
employee.info()

# %%
employee.fillna(0, inplace=True)

# %%
employee.info()

# %%
employee.describe().T

# %% [markdown]
# قد تلاحظ أن معرف الشركة هو رقم، لذا لا ينبغي أن يكون كذلك، فنحن نجعله سلسلة

# %%
employee['companyAlias'] = employee['companyAlias'].astype('str')

# %% [markdown]
# يمكنك أيضًا رؤية الفئة المستهدفة 16%

# %% [markdown]
# ##### الجزء 2.5.3. موظف. تحليل البيانات الاستكشافية، التحليل البصري للميزات <a id='part2.5.3'></a>

# %%
employee.hist(figsize=(12, 12));

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 8
sns.heatmap(employee.corr())
plt.title('Features Correlation Heatmap',fontsize=24)
plt.show()

# %% [markdown]
# في هذه الخريطة الحرارية يمكننا أن نرى الكثير من الأشياء المثيرة للاهتمام.
# يرتبط المتغير المستهدف جيدًا بمعلمات مثل:
# (أعجبني، يعني)، (txt_exist، يعني)، (txt_len، يعني)، (أعجبني، يعني)، num_emploees_by_company، (التصويت، يعني)

# %% [markdown]
# إذن هنا نرى الارتباطات مع الميزة المستهدفة.

# %%
employee.corr()['target'].abs().sort_values(ascending=False)[:10]

# %%
corr_feat = employee.corr()['target'].abs().sort_values(ascending=False)[:10].keys()

# %%
sns.boxplot(y='mean_vote_by_company', x='target', data=employee);

# %% [markdown]
# دعونا نرى كيف يبدي ممثلو الطبقات المختلفة عدم الإعجاب

# %%
sns.boxplot(y=('disliked', 'mean'), x='target', data=employee);

# %% [markdown]
# وتجدر الإشارة إلى أن الأشخاص الذين يرغبون في المغادرة يضعون قدرًا أقل من عدم الإعجاب بتعليقات الموظفين الآخرين.

# %%
sns.boxplot(y=('liked', 'mean'), x='target', data=employee);

# %% [markdown]
# ووضع عدد أقل من الإعجابات على تعليقات الموظفين الآخرين.

# %%
sns.boxplot(y=('txt_len', 'mean'), x='target', data=employee[employee[('txt_len', 'mean')] < 250]);

# %% [markdown]
# وأقل كتابة التعليقات.

# %% [markdown]
# ماذا عن الحصول على الإعجابات

# %%
sns.boxplot(y=('likes', 'mean'), x='target', data=employee[employee[('likes', 'mean')] < 20]);

# %%
sns.boxplot(y=('dislikes', 'mean'), x='target', data=employee[employee[('dislikes', 'mean')] < 2]);

# %% [markdown]
# ##### الجزء 2.5.4. موظف. الأنماط والرؤى وخصائص البيانات <a id='part2.5.4'></a>

# %% [markdown]
# يمكنك وضع الافتراضات التالية:
# 1. من المفترض أن الأشخاص المشاركين بنشاط في هذا التطبيق يتواصلون أيضًا بنشاط مع زملائهم ولا ينسحبون.
# 2. إذا كتب الشخص تعليقات، فمن المرجح أنه يريد العمل في الشركة.
# 3. كلما زاد عدد الموظفين، زاد معدل دوران الموظفين.

# %% [markdown]
# ### الجزء 3. التحليل البصري للميزات<a id='part3'></a>

# %% [markdown]
# ### الجزء الرابع. الأنماط والرؤى وخصائص البيانات <a id='part4'></a>

# %% [markdown]
# ### الجزء الخامس. المعالجة المسبقة للبيانات<a id='part5'></a>

# %% [markdown]
# ### الجزء السادس. هندسة الميزات ووصفها<a id='part6'></a>

# %% [markdown]
# تتم الأجزاء 3،4،5،6 لكل مجموعة بيانات على حدة، لسهولة القراءة. آسف، هذا أدى إلى تعقيد تقييم عملي، ولكن في رأيي أنه منطقي.

# %% [markdown]
# ### الجزء 7. التحقق من الصحة وضبط المعلمات الفائقة<a id='part7'></a>

# %% [markdown]
# نظرًا لأن لدينا اختلالًا قويًا في ميزة الهدف، فسوف نستخدم Train_test_split مع Stratify.<br>
# ولنموذج مناسب سوف نستخدم StratifiedKFold.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, roc_auc_score
from sklearn.model_selection import StratifiedKFold, train_test_split

y = employee['target']
X = employee.drop(['target', 'companyAlias'], axis=1).set_index('employee')
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3)

# %% [markdown]
# تأكد من أن توزيع الطبقات هو نفسه.

# %%
y.value_counts()[0]/y.value_counts()[1], \
y_test.value_counts()[0]/y_test.value_counts()[1], \
y_train.value_counts()[0]/y_train.value_counts()[1]

# %% [markdown]
# في مهمتنا، نتوقع إقالة الموظف. في مشكلتنا هناك نوعان من الأخطاء.
# أولاً، توقعنا أن الشخص سوف ينسحب، ولم ينسحب، أي بدلاً من 0 توقع 1. وهذا خطأ F1.
# ثانياً: نقول أن الإنسان يبقى، فيرحل. **هذا خطأ F2.** بالنسبة لمهمتنا، **الأمر أكثر أهمية**، لأننا نحاول تقليل التكاليف المرتبطة بتعيين موظفين جدد.

# %%
rf = RandomForestClassifier(random_state=17)
rf.fit(X_train, y_train)
# false negative - f2
# [tn, fp]
# [fn, tp]
confusion_matrix(y_train, rf.predict(X_train))

# %%
confusion_matrix(y_test, rf.predict(X_test))

# %%
import operator
sorted(zip(X_train.columns, rf.feature_importances_), key=operator.itemgetter(1), reverse=True)

# %%
skf = StratifiedKFold(n_splits=3)

def fit_grid_rf(params, cv=skf, X_train=X_train, y_train=y_train):
    rf_for_grid = RandomForestClassifier(random_state=17, n_jobs=-1, bootstrap=True)
    rf_grid = GridSearchCV(estimator=rf_for_grid, param_grid=params, cv=skf)
    rf_grid.fit(X_train, y_train)
    return rf_grid

def get_all_stats(grid, X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test):
    print('Best grid params: ', grid.best_params_)
    print('Best grid score: ', grid.best_score_)
    print('Confusion matrix for train: ', confusion_matrix(y_train, grid.best_estimator_.predict(X_train)))
    print('Confusion matrix for test: ', confusion_matrix(y_test, grid.best_estimator_.predict(X_test)))
    print('ROC AUC for train: ', roc_auc_score(y_train, grid.best_estimator_.predict_proba(X_train)[:, 1]))
    print('ROC AUC for test: ', roc_auc_score(y_test, grid.best_estimator_.predict_proba(X_test)[:, 1]))
    print('Best features', sorted(zip(X_train.columns, grid.best_estimator_.feature_importances_), key=operator.itemgetter(1), reverse=True)[:8])

# %% [markdown]
# دعونا نحاول تدريب شبكة البحث الأولى. لقد أعطيت هنا الكثير من الوزن لأمثلة طبقتنا الإيجابية.

# %% [markdown]
# ## أول بحث في الشبكة

# %%
# %%time
rf_params = {
    'n_estimators': [10, 50, 100],
    'max_depth': [5, 10, 15],
    'class_weight': [{0: 1, 1: 5}, {0: 1, 1: 9}],
    'max_features': [0.2, 0.5, 0.7,]
}
get_all_stats(fit_grid_rf(rf_params))

# %% [markdown]
# # بحث الشبكة الثانية

# %%
# %%time
skf = StratifiedKFold(n_splits=3)

rf_params = {
    'n_estimators': [100, 120],
    'max_depth': [15, 16],
    'class_weight': [{0: 1, 1: 5}],
    'max_features': [0.6, 0.7, 0.9],
    'criterion': ['gini', 'entropy']
}
get_all_stats(fit_grid_rf(rf_params))

# %% [markdown]
# ## بحث الشبكة الثالثة

# %%
# %%time
skf = StratifiedKFold(n_splits=3)

rf_params = {
    'n_estimators': [120],
    'max_depth': [16],
    'max_features': [0.7],
    'class_weight': [{0: 1, 1: 5}]
}
final_grid = fit_grid_rf(rf_params)
get_all_stats(final_grid)

# %% [markdown]
# دعونا نحاول ترك الميزات الرائعة فقط.

# %%
 X_train.columns

# %%
y = employee['target']

best_features = sorted(
    zip(
        X_train.columns, final_grid.best_estimator_.feature_importances_), key=operator.itemgetter(1), reverse=True
)
feats = []
for feat in best_features:
    feats.append(feat[0])
feats[:9]

# %% [markdown]
# لم تتغير النتيجة، 71 أخطاء F2 كثيرة جدًا.

# %% [markdown]
# وأهم مميزات هذا الموديل هي:<br>
# **num_emploees_by_company'** <br>
# **('أعجبني'، 'يعني')**<br>
# **('أعجبني'، 'مجموع')**<br>
# **first_last_vote_days**<br>
# **يعني_التصويت_من_الشركة**<br>
# **('txt_len', 'min')**<br>
# **عدد الأصوات**<br>
# **('تصويت'، 'يعني')**<br>
# **('txt_len', 'sum')** <br>

# %% [markdown]
# ### الجزء التاسع. التنبؤ بالعينات المحظورة والاختبارية <a id='part9'></a>

# %%
get_all_stats(final_grid)

# %% [markdown]
# ROC AUC للاختبار المعروف أيضًا باسم الاختبار = 0.911

# %% [markdown]
# ### الجزء 10. تقييم النموذج مع وصف المقاييس<a id='part10'></a>

# %% [markdown]
# لقد اخترت استخدام rock auk من أجل البساطة، ويمكنك تطويره لاحقًا واستخدام مقياس آخر

# %% [markdown]
# ### الجزء الحادي عشر. الاستنتاجات<a id='part11'></a>

# %% [markdown]
# هذه المهمة مهمة جدًا لتقليل تكاليف العثور على الموظفين وتكييفهم. على وجه الخصوص، هذه المهمة مهمة بالنسبة للشركات الكبيرة، لأن معدل دورانها أكبر.
# ونتيجة للبحث في مجموعة البيانات هذه، تبين أن فصل الموظف لا يعتمد بشكل كبير على ما إذا كان سعيدًا، بل يعتمد بشكل أكبر على حجم الشركة، ومدى نشاط الحياة الاجتماعية للموظف، وما إذا كان يتلقى الإعجابات من الموظفين ومدى تفاعله مع التطبيق.في المستقبل، يمكنك تجربة نماذج أخرى، مثل الانحدار اللوجستي، وربما ستتعامل بشكل جيد مع هذه المهمة. يمكنك أيضًا تحسين النموذج التنبؤي عن طريق زيادة حجم مجموعة البيانات.
