# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](https://mlcourse.ai) – دورة التعلم الآلي المفتوحة
# المؤلف: ماريا مانسوروفا، محللة ومطورة في فريق Yandex.Metrics. تمت الترجمة بواسطة إيفان زاخاروف، متحمس لتعلم الآلة. <br> تخضع هذه المادة لشروط وأحكام ترخيص [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). الاستخدام المجاني مسموح به لأي غرض غير تجاري.

# %% [markdown]
# # <center> المهمة رقم 9 (تجريبي)
# ## <center> تحليل السلاسل الزمنية
# ** نفس المهمة مثل [Kaggle Kernel](https://www.kaggle.com/kashnitsky/a9-demo-time-series-analysis) + [الحل](https://www.kaggle.com/kashnitsky/a9-demo-time-series-analysis-solution).**
# **املأ الخلايا المميزة بـ "الرمز الخاص بك هنا" وأرسل إجاباتك على الأسئلة من خلال [نموذج الويب](https://docs.google.com/forms/d/1UYQ_WYSpsV3VSlZAzhSN_YXmyjV7YlTP8EYMg8M8SoM/edit).**

# %%
import os
import warnings

warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import requests
from plotly import __version__
from plotly import graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot, plot

print(__version__)  # need 1.9.0 or greater
init_notebook_mode(connected=True)


def plotly_df(df, title=""):
    data = []

    for column in df.columns:
        trace = go.Scatter(x=df.index, y=df[column], mode="lines", name=column)
        data.append(trace)

    layout = dict(title=title)
    fig = dict(data=data, layout=layout)
    iplot(fig, show_link=False)

# %% [markdown]
# ## إعداد البيانات

# %%
df = pd.read_csv("../../data/wiki_machine_learning.csv", sep=" ")
df = df[df["count"] != 0]
df.head()

# %%
df.shape

# %% [markdown]
# ## التنبؤ مع الفيسبوك النبي
# سوف نقوم بالتدريب في أول 5 أشهر ونتوقع عدد الرحلات لشهر يونيو.

# %%
df.date = pd.to_datetime(df.date)

# %%
plotly_df(df.set_index("date")[["count"]])

# %%
from fbprophet import Prophet

# %%
predictions = 30

df = df[["date", "count"]]
df.columns = ["ds", "y"]
df.tail()

# %% [markdown]
# **<font color='red'>السؤال 1:</font>** ما هو توقع عدد مشاهدات صفحة الويكي في 20 يناير؟ التقريب إلى أقرب عدد صحيح.
# - 4947
# - 3426
# - 5229
# - 2744

# %%
# You code here

# %% [markdown]
# قم بتقدير جودة التنبؤ بآخر 30 نقطة.

# %%
# You code here

# %% [markdown]
# **<font color='red'>السؤال 2:</font> ما يساوي MAPE؟**
# - 34.5
# - 42.42
# - 5.39
# - 65.91
# **<font color='red'>السؤال 3:</font> ما هو MAE يساوي؟**
# - 355
# - 4007
# - 600
# - 903

# %% [markdown]
# ## التنبؤ باستخدام ARIMA

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats

plt.rcParams["figure.figsize"] = (15, 10)

# %% [markdown]
# **<font color='red'>السؤال 4:</font> دعونا نتحقق من ثبات السلسلة باستخدام اختبار ديكي-فولر. هل المسلسل ثابت؟ ما هي القيمة الاحتمالية؟**
# - المتسلسلة ثابتة، p_value = 0.107
# - السلسلة ليست ثابتة، p_value = 0.107
# - المتسلسلة ثابتة، p_value = 0.001
# - السلسلة ليست ثابتة، p_value = 0.001

# %%
# You code here

# %% [markdown]
# **بعد ذلك، ننتقل إلى بناء نموذج SARIMAX (`sm.tsa.statespace.SARIMAX`).<br> <font color='red'> السؤال 5:</font> ما هي المعلمات الأفضل للنموذج وفقًا لمعيار `AIC`؟**
# - د = 1، د = 0، س = 0، ف = 2، ف = 3، ص = 1
# - د = 2، د = 1، س = 1، ف = 2، ف = 3، ص = 1
# - د = 1، د = 1، س = 1، ف = 2، ف = 3، ص = 1
# - د = 0، د = 0، س = 0، ف = 2، ف = 3، ص = 1

# %%
# You code here
