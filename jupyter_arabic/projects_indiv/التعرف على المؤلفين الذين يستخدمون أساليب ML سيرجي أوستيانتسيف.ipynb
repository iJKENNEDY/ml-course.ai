# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## تعريف المؤلف
# المؤلفون: [سيرجي أوستيانتسيف]() (@schokoro).
# تخضع هذه المادة لشروط وأحكام ترخيص [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). الاستخدام المجاني مسموح به لأي غرض غير تجاري.

# %% [markdown]
# ### وصف المشكلةفي الأدب والتاريخ، غالبا ما يكون هناك سؤال حول الاعتراف بالأعمال الأدبية والاعتراف بتأليف مؤلف واحد أو آخر. هل قام شخص واحد بكتابة حوارات أفلاطون؟ هل كتب نفس العبقري كل مسرحيات شكسبير؟ وبدلاً من ذلك، هل قام أشخاص مختلفون بإنشاء كل هذه الأعمال؟ لفترة طويلة كان هناك نقاش حول هوية مؤلف رواية "والدون الهادئ يتدفق" وما إذا كان ميخائيل شولوخوف قد كتبها بالفعل. وأخيرًا، أثبتت الاختبارات اللغوية التي أجريت في الأعوام 1984 و1999 و2007 تأليف شولوخوف.
# والآن هناك موقف مشابه في روايتي "الكراسي الاثني عشر" و"العجل الذهبي". رسميا، مؤلفو الروايات هم إيليا إيلف ويفغيني بيتروف. إلا أن هناك فرضية بديلة مفادها أن المؤلف الحقيقي لتلك الروايات هو ميخائيل بولجاكوف. تمت دراسة النسخة من الناحية الأدبية والتاريخية \[1\]، \[2\]، لكن حتى الآن لم أقابل دراسات لغوية في هذا الموضوع. في هذا المشروع، سأحاول ملء الفجوة، ولنفترض، التحقق من الانسجام بمساعدة الجبر.
# يوجد حاليًا العديد من الطرق لتحديد الخصائص العددية للنصوص بناءً على أسلوب مؤلف النص. تسمح لنا هذه الخصائص بالتعرف على المؤلف وتسمى خصائص المؤلف الثابتة. إحدى هذه الطرق هي موضوع البحث في هذا المشروع.
# ### تعريف المشكلة
# في هذا المشروع سنفعل
# *البحث في طريقة التعرف على التأليف بناء على حساب المثلثات.
# * تحديد المعلمات المثلى لطريقة حل المشكلة المحددة.
# * تأكيد أو دحض الفرضية القائلة بأن مؤلف روايتي "12 كرسياً" و"العجل الذهبي" هو ميخائيل بولجاكوف.

# %% [markdown]
# ### إضفاء الطابع الرسمي على المشكلة. طرق الحل.
# وسوف نقوم بصياغة مشكلة التعرف على مؤلف النص مع مجموعة محدودة من البدائل على النحو التالي.
# هناك مجموعة من النصوص $T = \{ t_{1},..., t_{k} \}$ ومجموعة من المؤلفين $A = \{ a_{1},..., a_{n}\}$. بالنسبة لبعض المجموعات الفرعية من النصوص $T^{'} \subseteq T$، المؤلفون معروفون $D = \{(t_{i},\ a_{i})\}^{l}_{i=1}$. من الضروري العثور على المؤلف الحقيقي $A$ للنصوص (سواء كانت مجهولة أو مثيرة للجدل) $T^{''}=\{t_{|T|+1},...,\ t_{k}\} \subseteq T$.<br>
# تم وصف الطرق الرئيسية المستخدمة في هذا المشروع في الأعمال \[3\]، \[4\]. تختلف معلمات النماذج الموجودة في هذه الأعمال إلى حد ما ولكنها لا تتعارض مع بعضها البعض. جوهر الطريقة على النحو التالي.
# يمكن النظر إلى النص على أنه بنية هرمية وتحليله على أي مستوى كسلسلة من العناصر المكونة الفردية (الأحرف، وأشكال الكلمات، والفئات النحوية، وما إلى ذلك) أو مجموعات من العناصر بطول N، تسمى N-grams. يبدو تحليل النص أكثر تعقيدًا عند استخدام ميزات المستويات الأعلى من التسلسل الهرمي. لذلك، في عملية التحليل الصرفي، يتم استخدام المعلومات التي تم الحصول عليها في مرحلة التحليل المعجمي، وفي مرحلة التحليل النحوي، يتم استخدام المعلومات التي تم الحصول عليها في مرحلة التحليل الصرفي وما إلى ذلك. ونقتصر في هذه الدراسة على خصائص مستوى الشخصية؛ وهي أننا سوف نستخدم حسابات التريجرام للأحرف كأداة.

# %% [markdown]
# في الأعمال المذكورة أعلاه، استخدموا آلة دعم المتجهات مع نواة خطية، في حالة واحدة، ونواة وظيفة ذات أساس شعاعي، في حالة أخرى مثل خوارزميات التعلم الآلي. وكان العيب الشائع لهذه الأعمال هو عدم تعديل المعلمات المفرطة للنماذج. يتعلق الأمر في المقام الأول بمعدل التعلم بالقيمة المفترضة $C = 1$ افتراضيًا. عند إجراء النمذجة، في هذا المشروع، وجد أن القيم المثالية لـ $С$ تقع في نطاق $10^{-9} ... 10^{-1}$ وتعتمد على النموذج ومجموعة البيانات المحددة.

# %% [markdown]
# سوف نقوم بحساب تكرارات ظهور الأشكال الثلاثية في سلاسل فرعية يتراوح طولها من 1000 إلى 25000 رمز، مع الإشارة إلى أن حجم المتون محدود. في كل سلسلة فرعية، سنقوم بحساب الترددات الخاصة بـ $N$ التي يتم مواجهتها بشكل متكرر مع $N \in \{100 ... 2000\}$. علاوة على ذلك، لتقدير احتمالات ظهور الأشكال الثلاثية، سوف نطبق طريقة التجانس اللابلاسي، ونتحقق مما إذا كانت تؤثر على عمل النموذج.

# %% [markdown]
# ### طريقة الاستدلال وإعداد مجموعة البيانات النصيةإن المتطلبات الأساسية لمجموعة البيانات النصية المعدة لإجراء الدراسات اللغوية هي التمثيل والتوازن \[5\]. الشرط الأول يعني أن نموذج اللغة المقدم في المجموعة له دلالة إحصائية. الشرط الثاني يعني أن النصوص المجمعة في المجموعة تمثل البيانات بالتساوي.<br>
# للتعرف على المؤلفين، قمنا بإعداد مجموعة مؤلفة من أعمال أدبية مكتوبة في عشرينيات وثلاثينيات القرن العشرين. كان الاختيار بسبب الظروف التالية. في عشرينيات القرن العشرين، حدثت تغيرات اجتماعية كبيرة في المناطق التي يعيش فيها الناطقون بالروسية (في المقام الأول، في أراضي الاتحاد السوفييتي)، وتغيرت الطريقة العامة للحياة.<br>
# وبالمثل، عكست اللغة الروسية التغيرات في أشكال اللغة الجديدة والتغيرات الأخرى. كل ذلك أثر أيضًا على نموذج اللغة، فجعله مختلفًا عن النموذج الذي تأسس لاحقًا في منتصف القرن العشرين، وكذلك عن اللغة التي كان الناس يتحدثونها قبل أحداث 1917 الثورية.
# كما ذكرنا أعلاه، تضمنت مجموعة النصوص أعمالًا كتبت في النصف الثاني من عشرينيات القرن العشرين والنصف الأول من ثلاثينيات القرن العشرين. ربما تكون هذه القيود زائدة عن الحاجة، لكنها تسمح بالحصول على عينات لغوية لفترة معينة.<br>
# لتدريب النماذج، سنستخدم مجموعة "القطار" التي تعد بدورها مجموعة فرعية من مجموعة البيانات "الكبيرة". ويشمل أعمال ميخائيل بولجاكوف، وأركادي جيدار، ومكسيم غوركي، وألكسندر جرين، وإيليا إيلف، وإيفجيني بيتروف (بالتعاون)، وفالنتين كاتاييف، ويوري أوليشا، وأندريه بلاتونوف. لقد استخدمنا المجموعة "الكبيرة" لبناء نموذج لغوي، أي لحساب تكرارات ظهور الأشكال الثلاثية للأحرف. إلى جانب المؤلفين المذكورين في المجموعة "الكبيرة"، أضفنا مجموعة من المؤلفين من نفس الفترة إلى المجموعة.إنه نموذج.<br>
# جميع النصوص المقدمة مكتوبة بأحرف صغيرة. لقد أزلنا علامات الترقيم والأرقام والمسافات التي سمحت لنا بأخذ الرموز الكبيرة على حدود كلمتين في الاعتبار عند التحليل. وبذلك كان كل عمل عبارة عن سطر متصل يتكون من حروف أبجدية فقط.<br>
# لقد قمنا بإعداد مجموعة "الاختبار" بنفس المبدأ. لقد استخدمنا مجموعة "الاختبار" ليس لحساب ترددات المثلث أو تدريب النماذج، ولكن فقط لأغراض اختبار النماذج. تضمنت مجموعة "الاختبار" أعمال نفس المؤلفين المقدمة في مجموعة "القطار". تم وضع الأعمال المثيرة للجدل لـ Ilf وPetrov في دليل منفصل. <br>
# جميع البيانات المعدة [يمكنك تنزيلها هنا](https://drive.google.com/open?id=1fBhxBPXocqlkojMCBGvRnPkYiCH-JMV3)

# %% [markdown]
# ### تقدير الأشكال المثلثية، مقارنة المؤلفين حسب ترددات المثلثات
# دعنا نقدر عدد الأشكال الثلاثية التي تم العثور عليها للمؤلفين المدرجين في المجموعة "الكبيرة" والمدونة "التدريبية".

# %%
import re
from tqdm import tqdm_notebook
import pandas as pd
from matplotlib import pyplot as plt
from os import path, listdir
import seaborn as sns
import numpy as np
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pdb
import warnings
from pylab import rcParams
import random
from collections import defaultdict
from gc import collect
rcParams['figure.figsize'] = 12, 6
warnings.simplefilter('ignore')
# %matplotlib inline
#%config InlineBackend.figure_format = 'svg'

# %%
def make_freq_dict(file, f_dict, verbose=False):
    with open(file, 'r') as file_obj:
        string = file_obj.read()
    length = len(string)
    if verbose:
        print(f'{path.split(file)[1]} - {length} symbols')
    for i in range(length-2):
        ngram = string[i:i + 3]
        f_dict[ngram] = f_dict.get(ngram, 0) + 1
    if verbose:        
        print(f'В словаре {len(f_dict)} триграмм')
    return f_dict

# %%
f_dict = {}
full_corps = ''
PATH = '../corpus/'
files = listdir(PATH)
for file in files:
    f_dict = make_freq_dict(path.join(PATH, file), f_dict)
df = pd.Series(f_dict) 
df /= df.sum()
df.sort_values(ascending=False, inplace=True)
rcParams['figure.figsize'] = 12, 5
df.head(100).plot(kind='bar');

# %% [markdown]
# يوضح الرسم البياني أن سبعة من الأشكال الثلاثية أعلى بكثير من الأشكال الأخرى. ربما يجب أن نعتبرها “قمامة” لكثرتها النسبية ونتخلص منها، لكنها في المقابل قد تكون بمثابة إشارات واضحة. وسوف نتحقق منها خلال المزيد من التجارب أيضًا.
# دعونا نجمع مفردات فردية للترددات للمؤلفين التاليين: بولجاكوف، وإلف وبيتروف، وأوليشا، وبلاتونوف ونعرض 25 من الأشكال الثلاثية الأكثر استخدامًا بشكل مشترك، و25 من الأشكال الثلاثية الأكثر استخدامًا لكل مؤلف على حدة.

# %%
authors = ['Bulgakov', 'IlfPetrov', 'Olesha', 'Platonov']
colors = ['#ff7f0e','#98df8a', '#d62728', '#17becf']
#mp_colors = cm.set_array(np.array(colors))
all_dict = {}
for author in authors:
    f_dict = {}
    full_corps = ''
    PATH = '../corpus/'
    files = listdir(PATH)
    for file in files:
        if file.split('_')[0] == author:
            f_dict = make_freq_dict(path.join(PATH, file), f_dict)
    series_dict = pd.Series(f_dict)
    series_dict /= series_dict.sum()
    all_dict[author] = series_dict
    
particular_fdict = pd.DataFrame(all_dict)
particular_fdict = particular_fdict.loc[df.head(25).index]
particular_fdict.plot(kind='bar', grid=True, colors=colors);

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10));

axes = axes.flatten()
for i, author in enumerate(authors):
    df = particular_fdict[author].sort_values(ascending=False)
    axes[i].bar(df.index, df.values, color=colors[i]);
    axes[i].tick_params(axis='x', direction='in',labelrotation=90, grid_alpha=0.5);
    axes[i].legend([author]);
    axes[i].grid();

# %% [markdown]
# توضح الرسوم البيانية أن الترددات المختلفة لأشكال ثلاثية مختلفة تتوافق مع مؤلفين مختلفين، وكل مؤلف لديه "أعلى 25" خاصًا به، مما يعني أنه يمكن استخدام هذه الترددات كـ *ميزات* للتعرف.<br>
# لقد قمت بتأليف فئة `Recognizer` للعمل مع المجموعة. وصف أساليب الطبقة الرئيسية أدناه.

# %%
class Recognizer:
    def __init__(self, corpus_path):
        """
        :param corpus_path: path to corpus directory with string-books
        """
        self.path = corpus_path
        self.authors = ['Bulgakov', 'Gaidar', 'Gorky', 'Grin', 'IlfPetrov',
                        'Kataev', 'Olesha', 'Platonov']
        self.f_dict = defaultdict(int)
        self.string_corps = {writer: '' for writer in self.authors}
        self.make_dict_and_corps()
        self.trigrams = []
        self.estimators = {}

    def set_lang_model(self, string_size=5000, lang_model_size=100, skip=0, smoothing=False):
        """
        Sets parameters of language model
        :param string_size: length of substring
        :param lang_model_size: nums of the most frequently used trigrams for analys
        :param skip: num of skipped trigramms
        :param smoothing: on/off Laplacian smoothing
        """
        self.estimators = {}
        self.string_size=string_size
        self.trigrams = list(self.all_trigrams[skip: lang_model_size + skip].index)
        self.smoothing = smoothing

    def make_dict_and_corps(self):
        """
        Make dictionary and corpus for all authors in self.authors
        """
        books = listdir(self.path)
        for book in books:
            author = book.split('_')[0]
            with open(path.join(self.path, book)) as book_obj:
                string = book_obj.read()
                length = len(string)
                for i in range(length - 2):  # make a trigrams from string
                    ngram = string[i:i + 3]
                    self.f_dict[ngram] += 1
                if author in self.authors:
                    self.string_corps[author] += string
        self.all_trigrams = pd.Series(self.f_dict)
        self.all_trigrams.sort_values(ascending=False, inplace=True)

    def makesample(self, author, count=0, reverse=False, random_state=None):
        """
        :param author:
        :param count:0
        :param reverse: if True, method returns subsamples for all authors accept *author*
        :return: returns dataframe with trigrams frequencies
        """
        df_list = []
        if reverse:

            count *= len(self.authors) - 1
            string = ''
            for person in self.string_corps:
                if person is not author:
                    string += self.string_corps[person]
        else:
            string = self.string_corps[author]
        len_ = len(string)
        if count * self.string_size > len_:
            raise ValueError(f"{author} hasn't got a required text size ({count * self.string_size}) symbols.")
        if count == 0:
            count = len_ // self.string_size
        string_list = [string[i * self.string_size: ((i + 1) * self.string_size)] for i in range(len_ // self.string_size)]  # make a substrings
        random.seed(random_state)
        string_list = random.sample(string_list, count)
        for string in string_list:
            df_list.append(self.evaluate_trigrams(string))

        return pd.DataFrame(df_list)

    def evaluate_trigrams(self, substring):
        """
        Calculates frequencies of top-trigrams in string
        :param substring: input string (str)
        :return: dictionary, where keys are trigrams and values are trigrams frequencies
        """
        dyct = {key: 0 for key in self.trigrams}
        len_ = len(substring)
        count = 0
        for i in range(len_ - 2):
            ngram = substring[i:i + 3]
            if ngram in dyct:
                dyct[ngram] += 1
                count += 1
        if self.smoothing:
            return {key: (dyct[key] + 1)/(count + len(self.trigrams)) for key in dyct}
        else:
            return {key: dyct[key]/count for key in dyct}

    def one_against_one(self, model, params, author_1, author_2, scoring,
                        count=25, verbose=False, random_state=None):
        """
        Selects the optimal learning rate for the ML-model, 
        performs cross-validation of the model with the given parameters and authors.
        :param model: ML-model (sklearn model object)
        :param params: parameters of ML-model (dict)
        :param author_1: author_1 (str)
        :param author_2: author_2 (str)
        :param scoring: scoring
        :param count: number of substrings in sample
        :param verbose: 
        :return: mean value and standard deviation for cross_validation

        """
        if random_state:
            random_state1 = (hash(author_1) * random_state) % hash(author_2)
            random_state2 = (hash(author_2) * random_state) % hash(author_1)
        else:
            random_state1 = random_state2 = None
        model_name = re.findall(r'\w+', str(model).lower())[-1]  # it's a kind of magic
        cv = 5 if count > 5 else count
        df1 = self.makesample(author=author_1, count=count, random_state=random_state1)
        df2 = self.makesample(author=author_2, count=count, random_state=random_state2)
        y = np.hstack((np.ones(df1.shape[0]).astype(np.int), np.zeros(df1.shape[0]).astype(np.int)))
        pipe = make_pipeline(StandardScaler(), model(**params))
        X = pd.concat([df1, df2], axis=0)
        grid_params = {model_name + '__C': np.logspace(-8, 1, 10)}
        grid = GridSearchCV(pipe, param_grid=grid_params, scoring=scoring, n_jobs=-1, cv=cv, verbose=False).fit(X, y)
        cross_val = cross_val_score(grid.best_estimator_, X, y, cv=count, n_jobs=-1, scoring=scoring)
        mean_ = cross_val.mean()
        std_ = cross_val.std()
        if verbose:
            print(f'| mean = {cross_val.mean():.2f}, std = {cross_val.std():.2f} |')
        return np.array([mean_, std_])

    def make_df(self, text_path):
        """
        It gets a path to text-file, cuts the file into substrings of 'self.string_size' characters and calculates trigrams
         frequencies. Returns dataframe with trigrams frequencies.
        :param text_path: path to text file
        :return: pd.DataFrame
        """
        with open(text_path, 'r') as text_obj:
            string = text_obj.read()
        df_list = []
        len_ = len(string)
        string_list = [string[i * self.string_size: ((i + 1) * self.string_size)] \
                       for i in range(len_ // self.string_size)]
        for string in string_list:
            df_list.append(self.evaluate_trigrams(string))
        return pd.DataFrame(df_list)

    @staticmethod
    def softmax(X):
        """
        My own softmax with numpy and vecotorizing :7
        """
        y = np.atleast_2d(X)
        y = y - np.expand_dims(np.max(y, axis=1), 1)
        y = np.exp(y)
        ax_sum = np.expand_dims(np.sum(y, axis=1), 1)
        p = y / ax_sum
        if len(X.shape) == 1:
            p = p.flatten()
        return p

    def fit(self, model, params, mode, train_size=25, random_state=None):
        """
        Fit the ML-models according to the given training data.
        :param model: ML-model (sklearn model object)
        :param params: parameters of ML-model
        :param mode: 'oao' - one-against-one or 'oaa' - one-against-all
        :param train_size: length of string for evaluate trigrams
        :return: None
        """
        self.mode = mode
        self.random_state = random_state
        self.train_size = train_size
        self.model = model
        self.params = params
        model_name = re.findall(r'\w+', str(model).lower())[-1]
        cv = 5 if train_size > 5 else train_size
        if not self.trigrams:
            raise RuntimeWarning(' Set a language model first!')
        n_authors = len(self.authors)
        self.estimators = {}
        for i in range(n_authors):
            df1 = self.makesample(author=self.authors[i], count=train_size, random_state=random_state + i)
            if mode == 'oao': # one against one
                for j in range(i):
                    df0 = self.makesample(author=self.authors[j], count=train_size, random_state=random_state + 3*i + 5*j)
                    X = pd.concat([df1, df0], axis=0)
                    y = np.hstack((np.ones(df1.shape[0]).astype(np.int),
                                   np.zeros(df0.shape[0]).astype(np.int)))
                    pipe = make_pipeline(StandardScaler(), model(**params))
                    grid_params = {model_name + '__C': np.logspace(-9, 1, 21)}
                    grid = GridSearchCV(pipe, param_grid=grid_params,
                                        scoring='accuracy',
                                        n_jobs=-1,
                                        cv=cv).fit(X, y)
                    self.estimators[frozenset([self.authors[i], self.authors[j]])] = {
                        'estimator': grid.best_estimator_,
                        'target': [self.authors[j], self.authors[i]]
                    }
            elif mode == 'oaa': # one against all
                df0 = self.makesample(author=self.authors[i], count=train_size, reverse=True)
                X = pd.concat([df1, df0], axis=0)
                y = np.hstack((np.ones(df1.shape[0]).astype(np.int),
                               np.zeros(df0.shape[0]).astype(np.int)))
                pipe = make_pipeline(StandardScaler(), model(**params))
                grid_params = {model_name + '__C': np.logspace(-9, 1, 21)}
                grid = GridSearchCV(pipe, param_grid=grid_params, scoring='roc_auc', n_jobs=-1).fit(X, y)
                self.estimators[self.authors[i]] = grid
        return

    def predict(self, text_path):
        """
        Возвращает автора из корпуса, максимально соответствующего тексту. Выбор осуществляется мажоритарным
        голосованием по accuracy.
        :param text_path:
        :return: string: author of input text (tuple of strings)
        """
        if not self.estimators:
            raise RuntimeWarning("Run 'fit'-method first")
        test_df = self.make_df(text_path)
        result = defaultdict(int)
        df_result = pd.DataFrame(index=test_df.index, columns=self.authors).fillna(0)
        for key in self.estimators:
            if self.mode == 'oaa':  # one against all
                pred = self.estimators[key].predict(test_df).sum()
                result[key] += pred
                df_result[key] = self.estimators[key].predict(test_df)
            elif self.mode == 'oao': # one against one
                estimator = self.estimators[key]['estimator']
                target = self.estimators[key]['target']
                df_result[target[1]] += estimator.predict(test_df)
                df_result[target[0]] += -1 * (estimator.predict(test_df) -1)
            else:
                raise ValueError("incorrect parameter value")
        author_sum = df_result.sum()
        return author_sum[author_sum == author_sum.max()].index[0]

    def hypothesis_test(self, text_path, author_1, author_2, softmax=False):
        """
        Returns the probabilities of a work accessory for two  authors.
        :param text_path: path to text file
        :param author_1: first author
        :param author_2: second author
        :return: pd.Series of probabilities
        """
        if not self.estimators:
            raise RuntimeWarning("Run 'fit'-method first")
        if self.random_state:
            random_state1 = (hash(author_1) * self.random_state) % hash(author_2)
            random_state2 = (hash(author_2) * self.random_state) % hash(author_1)
        else:
            random_state1 = random_state2 = None

        keys = list(self.estimators.keys())
        test_df = self.make_df(text_path)

        if self.mode == 'oao':
            dict_estimator = self.estimators[frozenset([author_1, author_2])]
            target = dict_estimator['target']
            pred = dict_estimator['estimator'].predict(test_df)
            pred = pred.sum()/test_df.shape[0]
            return pd.Series({target[1]: pred, target[0]: 1 - pred})

        elif self.mode == 'oaa':
            if softmax:
                pred1 = self.estimators[author_1].predict_proba(test_df)
                pred2 = self.estimators[author_2].predict_proba(test_df)
                pred = self.softmax(np.vstack((pred1[: ,1], pred2[: ,1].T)).T)
                #print(pred)
                #pdb.set_trace()
                return pd.Series(pred.mean(axis=0), index=[author_1, author_2])
            else:
                model = self.model
                model_name = re.findall(r'\w+', str(model).lower())[-1]
                cv = 5 if self.train_size > 5 else self.train_size
                df1 = self.makesample(author=author_1, count=self.train_size, random_state=random_state1)
                df0 = self.makesample(author=author_2, count=self.train_size, random_state=random_state2)

                X = pd.concat([df1, df0], axis=0)
                y = np.hstack((np.zeros(df1.shape[0]).astype(np.int), np.ones(df0.shape[0]).astype(np.int)))
                pipe = make_pipeline(StandardScaler(), model(**self.params))
                grid_params = {model_name + '__C': np.logspace(-9, 1, 21)}
                grid = GridSearchCV(pipe, param_grid=grid_params, scoring='roc_auc', n_jobs=-1, cv=cv).fit(X, y)
                #pdb.set_trace()
                pred = grid.predict_proba(test_df)
                return pd.Series(pred.mean(axis=0), index=[author_1, author_2])
        else:
            raise KeyError

# %% [markdown]
# ##### وصف الفصل
# يحتوي منشئ الفئة على معلمة إلزامية واحدة، وهي المسار إلى مجموعة النصوص المستخدمة لتدريب النموذج.<br>
# * تقوم طريقة ***set_lang_model*** بضبط معلمات نموذج اللغة، أي عدد الأشكال الثلاثية المستخدمة، وطول السلسلة الفرعية لحساب عدد الأشكال الثلاثية، وعدد الأشكال الثلاثية الأولية التي تم تخطيها، وتشغيل أو إيقاف تشغيل التجانس.
# * تحصل طريقة ***one_against_one*** على فئة من نماذج التعلم الآلي عند الإدخال، أي مؤلفين وحجم العينات. بعد ذلك، يقوم الأسلوب `makesample` بإنشاء نماذج من النص بحجم معين لكل مؤلف. بعد ذلك، تحدد الطريقة معدل التعلم الأمثل لنموذج ML، بمساعدة `GridSearchCV`. وأخيرا، تحسب الطريقة احتمالية التعرف الصحيح على المؤلف في التحقق المتبادل لأفضل مقدر. عدد الطيات يساوي عدد السلاسل الفرعية في العينات لكل مؤلف. نظرًا لأن أحجام العينات صغيرة نسبيًا، فإن التحقق المتبادل لا يستغرق الكثير من الوقت.
# * تقوم طريقة ***fit*** بتعليم مصنفات M للمؤلفين N على عينات فرعية ذات حجم معين. بالنسبة للمخطط `one against one` $M = \frac{N(N-1)}{2}$، بالنسبة للمخطط` one against all` $M=N$
# * تستقبل طريقة ***التنبؤ*** المسار إلى الملف النصي وتعيد مؤلف النص باستخدام المصنفات المدربة.
# * طريقة ***hypothesis_test*** تحصل على المسار إلى الملف النصي، مؤلفين وتعيد احتمالات انتماء النصوص المحددة إلى المؤلفين المحددين.

# %% [markdown]
# .

# %%
recognizer = Recognizer('../corpus/')

# %% [markdown]
# سنقوم بإصلاح طول الأجزاء بما يعادل 5000 حرف ونقدر احتمالية التعرف الصحيح على المؤلف بكميات مختلفة من الأشكال الثلاثية الأكثر شيوعًا في نطاق 100 إلى 3000 ونجري تجارب على `SVM` مع النواة الخطية وrbf ومع الانحدار اللوجستي. نظرًا لأن خوارزمية SVM لا يمكنها التنبؤ باحتمالات الفصل، فإنها تقوم فقط بإرجاع تسميات الفصل، باستخدام `'accuracy'` كمقاييس. بالنسبة إلى `LogisticRegression`، سنستخدم أيضًا المقياس `'accuracy'` للمقارنة الصحيحة مع SVM.

# %%
def calculate_errors(recognizer, model, params, scoring='accuracy', length_string=5000,
                     n_3gramms=300, random_state=None):
    recognizer.set_lang_model(lang_model_size=n_3gramms, skip=0, smoothing=False, string_size=length_string)
    errors = {}
    authors = recognizer.authors
    n_authors = len(authors)
    for i in range(n_authors):
        for j in range(i):
            mean, std = recognizer.one_against_one(model, params, authors[i], authors[j],
                                                   scoring, 20, random_state=random_state)
            errors['_'.join([authors[i], authors[j]])] = (mean)
    return errors

# %%
#SVM with linear kernel
params = {'random_state':42, 'kernel': 'linear'} 
df_list = {}
for ngrams in tqdm_notebook(range(100, 3100, 100)):
    df_list[ngrams] = calculate_errors(recognizer, SVC, params, n_3gramms=ngrams, random_state=ngrams)
df_errors_svl = pd.DataFrame(df_list)
f, ax = plt.subplots(1, 1)
sns.boxplot(data=df_errors_svl, ax=ax);
sns.pointplot(data=df_errors_svl.values, linestyles='', scale=1, color='k', errwidth=1.5, capsize=0.2, markers='x')
sns.pointplot(data=df_errors_svl.values, linestyles='--', scale=0.4, color='k', errwidth=0, capsize=0, ax=ax)
ax.set_ylabel('P'); ax.set_xlabel('3-gramms'); ax.set_xticklabels([t for t in range(100, 3100, 100)]);
plt.gcf().autofmt_xdate(); ax.grid(); plt.show()

# %%
#SVM with rbf kernel
params = {'random_state':42, 'kernel': 'rbf'} 
df_list = {}
for ngrams in tqdm_notebook(range(100, 3100, 100)):
    df_list[ngrams] = calculate_errors(recognizer, SVC, params, n_3gramms=ngrams, random_state=ngrams)
df_errors_svr = pd.DataFrame(df_list)
f, ax = plt.subplots(1, 1)
sns.boxplot(data=df_errors_svr, ax=ax);
sns.pointplot(data=df_errors_svr.values, linestyles='', scale=1, color='k', errwidth=1.5, capsize=0.2, markers='x')
sns.pointplot(data=df_errors_svr.values, linestyles='--', scale=0.4, color='k', errwidth=0, capsize=0, ax=ax)
ax.set_ylabel('P'); ax.set_xlabel('3-gramms'); ax.set_xticklabels([t for t in range(100, 3100, 100)]);
plt.gcf().autofmt_xdate(); ax.grid(); plt.show()

# %%
#Logistic regression
params={'random_state':42, 'class_weight':'balanced', 'solver':'liblinear'} 
df_list = {}
for ngrams in tqdm_notebook(range(100, 3100, 100)):
    df_list[ngrams] = calculate_errors(recognizer, LogisticRegression, params, n_3gramms=ngrams, random_state=ngrams) #, scoring='roc_auc'
df_errors_lr = pd.DataFrame(df_list)
f, ax = plt.subplots(1, 1)
sns.boxplot(data=df_errors_lr, ax=ax);
sns.pointplot(data=df_errors_lr.values, linestyles='', scale=1, color='k', errwidth=1.5, capsize=0.2, markers='x')
sns.pointplot(data=df_errors_lr.values, linestyles='--', scale=0.4, color='k', errwidth=0, capsize=0, ax=ax)
ax.set_ylabel('P'); ax.set_xlabel('3-gramms'); ax.set_xticklabels([t for t in range(100, 3100, 100)]);
plt.gcf().autofmt_xdate(); ax.grid(); plt.show()

# %%
#summary graph for trigramms
trigramms = df_errors_lr.columns
df1 = pd.DataFrame({'trigramms': trigramms, 'P': df_errors_svl.mean()})
df2 = pd.DataFrame({'trigramms': trigramms, 'P': df_errors_svr.mean()})
df3 = pd.DataFrame({'trigramms': trigramms, 'P': df_errors_lr.mean()})
f, ax = plt.subplots(1, 1)
x_col='trigramms'
y_col = 'P'
sns.pointplot(ax=ax,x=x_col,y=y_col,data=df1,color='blue', linestyles='-' , scale=.8, markers='.')  #, capsize=1
sns.pointplot(ax=ax,x=x_col,y=y_col,data=df2,color='green', linestyles='-', scale=.8, markers='.')
sns.pointplot(ax=ax,x=x_col,y=y_col,data=df3,color='red', linestyles='-', scale=.8, markers='.')
ax.legend(handles=ax.lines[::len(df1)+1], labels=["SVC_linear","SVC_rbf","LogReg"]); ax.grid()
ax.set_xticklabels([t for t in range(100, 3100, 100)]); plt.gcf().autofmt_xdate(); plt.show()

# %% [markdown]
# يُظهر SVM الخطي والانحدار اللوجستي نتيجة أفضل قليلاً. يعمل SVM مع rbf kernel بشكل أسوأ قليلاً، خاصة فيما يتعلق بعدد 1000 تريجرام أو أعلى.<br>
# سنقوم بإصلاح عدد الأشكال الثلاثية بما يساوي 300 ونقدر احتمالية التعرف الصحيح على مؤلف الأجزاء ذات الأطوال المختلفة من 1000 إلى 20000 حرف.

# %%
#Logistic regression
params = {'random_state':42, 'kernel': 'linear'}
df_list = {}
for length in tqdm_notebook(range(1000, 31000, 1000)):
    df_list[length] = calculate_errors(recognizer, SVC, params, length_string=length, random_state=length)
df_errors_svl = pd.DataFrame(df_list)
f, ax = plt.subplots(1, 1)
sns.boxplot(data=df_errors_svl, ax=ax);
sns.pointplot(data=df_errors_svl.values, linestyles='', scale=1, color='k', errwidth=1.5, capsize=0.2, markers='x')
sns.pointplot(data=df_errors_svl.values, linestyles='--', scale=0.4, color='k', errwidth=0, capsize=0, ax=ax)
ax.set_ylabel('P'); ax.set_xlabel('length of string'); ax.set_xticklabels([t for t in range(1000, 31000, 1000)])
plt.gcf().autofmt_xdate(); ax.grid(); plt.show()

# %%
#SVM with rbf kernel
params = {'random_state':42, 'kernel': 'rbf'} 
df_list = {}
for length in tqdm_notebook(range(1000, 31000, 1000)):
    df_list[length] = calculate_errors(recognizer, SVC, params, length_string=length, random_state=length) 
    
df_errors_svr = pd.DataFrame(df_list)
f, ax = plt.subplots(1, 1)
sns.boxplot(data=df_errors_svr, ax=ax);
sns.pointplot(data=df_errors_svr.values, linestyles='', scale=1, color='k', errwidth=1.5, capsize=0.2, markers='x')
sns.pointplot(data=df_errors_svr.values, linestyles='--', scale=0.4, color='k', errwidth=0, capsize=0, ax=ax)
ax.set_ylabel('P'); ax.set_xlabel('length of string'); ax.set_xticklabels([t for t in range(1000, 31000, 1000)])
plt.gcf().autofmt_xdate(); ax.grid(); plt.show()

# %%
#Logistic regression
params={'random_state':42, 'class_weight':'balanced', 'solver':'liblinear'} #, 'C': 1e-7
df_list = {}
for length in tqdm_notebook(range(1000, 31000, 1000)):
    df_list[length] = calculate_errors(recognizer, LogisticRegression, params, length_string=length, random_state=length) 
df_errors_lr = pd.DataFrame(df_list)
f, ax = plt.subplots(1, 1)
sns.boxplot(data=df_errors_lr, ax=ax);
sns.pointplot(data=df_errors_lr.values, linestyles='', scale=1, color='k', errwidth=1.5, capsize=0.2, markers='x')
sns.pointplot(data=df_errors_lr.values, linestyles='--', scale=0.4, color='k', errwidth=0, capsize=0, ax=ax)
ax.set_ylabel('P'); ax.set_xlabel('length of string'); ax.set_xticklabels([t for t in range(1000, 31000, 1000)])
plt.gcf().autofmt_xdate(); ax.grid(); plt.show()

# %%
#summary graph for trigramms
string_length = df_errors_lr.columns
df1 = pd.DataFrame({'string_length': string_length, 'P': df_errors_svl.mean()})
df2 = pd.DataFrame({'string_length': string_length, 'P': df_errors_svr.mean()})
df3 = pd.DataFrame({'string_length': string_length, 'P': df_errors_lr.mean()})
f, ax = plt.subplots(1, 1)
x_col='string_length'
y_col = 'P'
sns.pointplot(ax=ax,x=x_col,y=y_col,data=df1,color='blue', linestyles='-' , scale=.8, markers='.')  #, capsize=1
sns.pointplot(ax=ax,x=x_col,y=y_col,data=df2,color='green', linestyles='-', scale=.8, markers='.')
sns.pointplot(ax=ax,x=x_col,y=y_col,data=df3,color='red', linestyles='-', scale=.8, markers='.')
ax.legend(handles=ax.lines[::len(df1)+1], labels=["SVC_linear","SVC_rbf","LogReg"])
ax.set_xticklabels([t for t in range(1000, 31000, 1000)])
plt.gcf().autofmt_xdate()
ax.grid()
plt.show()

# %% [markdown]
# وهنا، تكون نتائج النماذج الثلاثة متساوية تقريبًا. عند أطوال سلسلة تصل إلى 2000 حرف، يكون أداء الانحدار اللوجستي وSVM مع rbf kernel أفضل قليلاً. علاوة على ذلك، تظهر جميع الخوارزميات نفس النتائج تقريبًا. بالنسبة للأسطر التي يبلغ طولها 3000 حرف، ترتفع دقة التعرف على المؤلف إلى $p > 0.9$.

# %% [markdown]
# دعونا نقدر تأثير الرموز السبعة الأولية على جودة التعرف على المؤلف. سوف نستخدم SVM الخطي، وعدد الأشكال الثلاثية التي تم تحليلها هو 250، وطول السلسلة الفرعية هو 5000.

# %%
recognizer.set_lang_model(lang_model_size=250, skip=0, smoothing=False, string_size=5000)
n_mean = 0
n = 500
for i in tqdm_notebook(range(n)):
    random.seed(i)
    author1, author2 = random.sample(recognizer.authors, 2)
    params = {'random_state':n, 'kernel': 'linear'}
    mean, std = recognizer.one_against_one(SVC, params, author1, author2, 'accuracy', 25, random_state=i)
    n_mean += mean
print(f'{n_mean / n:.5f}')

# %%
recognizer.set_lang_model(lang_model_size=250, skip=7, smoothing=False, string_size=5000)
n_mean = 0
n = 500
for i in tqdm_notebook(range(n)):
    random.seed(i)
    author1, author2 = random.sample(recognizer.authors, 2)
    params = {'random_state':n, 'kernel': 'linear'}
    mean, std = recognizer.one_against_one(SVC, params, author1, author2, 'accuracy', 25, random_state=i)
    n_mean += mean
print(f'{n_mean / n:.5f}')

# %% [markdown]
# عند تخطي الرموز السبعة الأولية، يتغير احتمال التعرف على المؤلف قليلاً.

# %% [markdown]
# ### تقييم تأثير تجانس لابلاسعند حساب ترددات ظهور N-grams في النص كميزات لتحديد هوية المؤلف، يمكن للباحث العثور على بيانات متفرقة. ويحدث ذلك عندما يكون جزء من العلامات مفقودًا في المجموعة المقدرة نظرًا لعدم وجود عينة عامة من البيانات المستخدمة. في المقام الأول، هذه المشكلة ذات صلة بالنصوص ذات الأحجام الصغيرة والجرامات ذات الرتب العالية. حل المشكلة هو استخدام تقنيات خاصة لتسوية الاحتمالات (طرق لابلاس، جود تورينج، طريقة استيفاء كاتز، طريقة كنيسر-ناي، إلخ. \[6\])، مما يسمح بتقدير احتمالات الأحداث غير الواقعة. في الأعمال \[3\]، \[4\]، أثبت تجانس لابلاس أنه الأفضل.
# لحساب احتمالات N-gram مع مراعاة التجانس الإضافي، سوف نستخدم التعبير التالي: <br>
# $P_{ADD}(w_{i-n+1}^{i-1})=\frac{\delta+c(w_{i-n+1}^{i})}{\delta V + \sum \limits_{w_{i}} c(w_{i-n+1}^{i})}$,<br>
# حيث c (·) هو عدد استخدامات N-gram معين؛ V هو عدد جميع N-grams في المفردات المستخدمة.
# تجانس لابلاس هو حالة خاصة من التجانس الإضافي باستخدام $delta = 1$
# لتقييم تأثير تجانس لابلاس، سنجري 500 تجربة مستقلة مع تشغيل وإيقاف التجانس لأزواج مؤلفين تم اختيارهم عشوائيًا لمقارنة احتمالات التعرف الصحيح.
# ولنجري هذه التجارب في مسألتين:
# 1. عدد الأشكال الثلاثية هو 1000، وطول السلسلة الفرعية 4000؛ في هذه الحالة، هناك بيانات متفرقة، ويمكن أن يكون استخدام التجانس فعالاً
# 2. عدد المثلثات 300، طول السلسلة الفرعية 20000؛ وفي هذه الحالة، لا توجد أية بيانات متفرقة.
# نتوقع أنه في الحالة الأولى ستختلف النتائج مع التجانس عن النتائج بدون التجانس.

# %%
recognizer.set_lang_model(lang_model_size=1000, skip=0, smoothing=False, string_size=4000)
n_mean = 0
params = {'C': 1, 'kernel': 'linear'}
n = 500
for i in tqdm_notebook(range(n)):
    random.seed(i*42)
    author1, author2 = random.sample(recognizer.authors, 2)    
    params = {'random_state':n, 'kernel': 'rbf'}
    #params={'random_state':42, 'class_weight':'balanced', 'solver':'liblinear'}
    mean, std = recognizer.one_against_one(SVC, params, author1, author2, 'accuracy', 10, random_state=i)
    n_mean += mean
print(f'{n_mean / n:.5f}')

# %%
recognizer.set_lang_model(lang_model_size=1000, skip=0, smoothing=True, string_size=4000)
n_mean = 0
n = 500
for i in tqdm_notebook(range(n)):
    random.seed(i*42)
    author1, author2 = random.sample(recognizer.authors, 2)
    params = {'random_state':n, 'kernel': 'rbf'}
    mean, std = recognizer.one_against_one(SVC, params, author1, author2, 'accuracy', 10, random_state=i)
    n_mean += mean
print(f'{n_mean / n:.5f}')

# %%
recognizer.set_lang_model(lang_model_size=300, skip=0, smoothing=False, string_size=20000)
n_mean = 0
n = 500
for i in tqdm_notebook(range(n)):
    random.seed(i*42)
    author1, author2 = random.sample(recognizer.authors, 2)
    params = {'random_state':n, 'kernel': 'rbf'}
    mean, std = recognizer.one_against_one(SVC, params, author1, author2, 'accuracy', 10, random_state=i)
    n_mean += mean
print(f'{n_mean / n:.5f}')

# %%
recognizer.set_lang_model(lang_model_size=300, skip=0, smoothing=True, string_size=20000)
n_mean = 0
n = 500
for i in tqdm_notebook(range(n)):
    random.seed(i*42)
    author1, author2 = random.sample(recognizer.authors, 2)
    params = {'random_state':n, 'kernel': 'rbf'}
    mean, std = recognizer.one_against_one(SVC, params, author1, author2, 'accuracy', 10, random_state=i)
    n_mean += mean
print(f'{n_mean / n:.5f}')

# %% [markdown]
# وكما نرى فإن التجانس يؤثر قليلاً على النتيجة في كلتا الحالتين. ربما يكون هذا بسبب استخدام عينات أصغر بكثير في \[3\] و \[4\]، بمقدار 2 لكل مؤلف ولم يتم إجراء أي تسوية للنموذج.

# %% [markdown]
# ## التعرف على المؤلف
# حتى الآن، حاولنا التنبؤ بالمؤلف لعينة واحدة من النص لجميع الأزواج المحتملة من المؤلفين $(M = \frac{N(N-1)}{2})$، حيث $N$ هو عدد المؤلفين.
# بشكل عام، يتكون كل نص من عدة أجزاء وقد يزيد عدد المؤلفين المحتملين عن اثنين.
# دعونا ننظر في مشكلة التصنيف متعدد الفئات. في البداية، تم تدريب جميع المصنفات في مجموعة "التدريب" للتعرف على جميع المؤلفين من قائمة أدوات التعرف. تم تعيين حجم العينة الفرعية للتدريب بواسطة المعلمة `train_size` للطريقة` fit`. بالنسبة للمصنفات المستندة إلى SVM، قمنا بتطبيق مخطط `one against one`، وتم تدريب كل مصنف على عينات فرعية متساوية لكل مؤلف. بالنسبة إلى الانحدار اللوجستي، تم تطبيق مخطط `one against all`، وتم تدريب كل مصنف على عينة فرعية *من مؤلفه* وعينة فرعية $N-1$ من جميع المؤلفين الآخرين. وبالتالي كانت عينة التدريب غير متوازنة.
# تم تنفيذ التعرف على المؤلف بواسطة طريقة `predict`. وكانت عملية الاعتراف على النحو التالي. تم تقسيم نموذج النص بأكمله إلى سلاسل فرعية بالطول المحدد، مع إجمالي عدد السلاسل الفرعية $ m $. قمنا بحساب عدد الأشكال الثلاثية لكل سلسلة فرعية. وهكذا، حصلنا على مصفوفة بحجم $m \times l$، حيث $l$ هو عدد الأشكال الثلاثية التي يتم حسابها في نموذج اللغة - *lang_model_size*. بعد ذلك، تم تمرير المصفوفة إلى الأسلوب `predict` لكل مصنف. وهكذا، بالنسبة لكل من السلاسل الفرعية، حصلنا على توقعات الاعتراف بالمؤلف. تم تلخيص التوقعات الإيجابية بواسطة المصنفات والسلاسل الفرعية، ثم تم الاختيار النهائي للمؤلف من خلال تصويت الأغلبية للنص بأكمله.
# بالنسبة إلى `LogisticRegression` في مخطط `one against all`، اخترنا طريقة `predict` بدلاً من ذلكd لـ ` predict_proba` حيث تبين أن هناك نتيجة نهائية أكثر دقة.
# في التجارب السابقة حصلنا على نتائج ممتازة لسلسلة فرعية بطول 20000 حرف وعدد ثلاثيات 2000. علاوة على ذلك، سوف نطبق هذه القيم. لن نستخدم التجانس أو تخطي الأشكال الثلاثية الأولية.
# سوف نتعرف على مؤلف كل نص من مجموعة الاختبار ونعرض النتائج في جدول. وفي حالة ظهور نتيجة غير صحيحة، سنعرض أيضًا اسم الملف الذي يحتوي على خطأ التوقع.

# %%
test_corpus = '../test_corpus/'
ilf_petrov = '../IlfPetrov/'
string_size = 20000
train_size=15
lang_model_size=2000

recognizer.set_lang_model(lang_model_size=lang_model_size,
                          skip=0, smoothing=False,
                          string_size=string_size)

def predict_author(recognizer, PATH='../test_corpus/'):
    files = listdir(PATH)
    true = 0
    all = 0
    print(' ________________________________________ ')
    print('| real author | predicted author| matched ')
    
    for file in files:
        author = file.split('_')[0]
        if author in recognizer.authors:
            all += 1
            pred_author =  recognizer.predict(path.join(PATH, file))#   path.join((path, ))
            print( f'| {author}{" " * (12 - len(author))}|  {pred_author}{" " * (15 - len(pred_author))}| {author == pred_author}', end=" ")
            if author == pred_author:
                true +=1
                print()
            else:
                print(file)
    print('|________________________________________ ')    
    if PATH != '../IlfPetrov/':
        print(f'Accuracy {100 * true / all:.2f}%', end='\n\n')

# %% [markdown]
# #### SVM مع نواة *خطية*

# %%
params = {'random_state':42, 'kernel':'linear'} 
recognizer.fit(model=SVC, params=params, mode='oao', train_size=train_size, random_state=42)
predict_author(recognizer=recognizer, PATH=test_corpus)
predict_author(recognizer=recognizer, PATH=ilf_petrov)

# %% [markdown]
# #### SVM مع نواة *rbf*

# %%
params = {'random_state':42,'kernel':'rbf'}
recognizer.fit(model=SVC, params=params, mode='oao', train_size=train_size, random_state=42)
predict_author(recognizer=recognizer, PATH=test_corpus)
predict_author(recognizer=recognizer, PATH=ilf_petrov)

# %% [markdown]
# #### الانحدار اللوجستي

# %%
params={'random_state':42, 'class_weight':'balanced', 'solver':'liblinear'}
recognizer.fit(model=LogisticRegression, params=params, mode='oaa', train_size=train_size, random_state=42)
predict_author(recognizer=recognizer, PATH=test_corpus)
predict_author(recognizer=recognizer, PATH=ilf_petrov)

# %% [markdown]
# يُظهر Linear SVM وLogisticRegression أفضل النتائج في مجموعة التدريب، وكلاهما يعرف بولجاكوف بأنه مؤلف رواية "الكراسي الاثني عشر"، لكن SVM الخطي يُعرّف Ilf وPetrov بأنهما مؤلفا "Golden Calf". يظهر SVM مع RBF kernel نتيجة أسوأ، لكنه يتعرف على بولجاكوف كمؤلف لكلا الروايتين.

# %% [markdown]
# ## اختبار فرضية التأليففي التجربة السابقة، لم نتمكن من تحديد مؤلف روايتي "الكراسي الاثني عشر" و"العجل الذهبي" بشكل لا لبس فيه. سنطرح سؤالاً صارمًا من هو المؤلفان، إيلف وبيتروف، أم بولجاكوف؟
# لتحديد المؤلف المقترح، في فئة أداة التعرف، سنستخدم طريقة `hypothesis_test` الخاصة بفئتنا. في مخطط `one against one`، كل شيء بسيط. لقد حصلنا بالفعل على مصنفات مدربة لكل زوج من المؤلفين، ويكفي استخدامها للتعرف عليها.
# إذا كان هناك مصنفون تم تدريبهم على مخطط `one against one`، فلدينا احتمالان:
# * بالنسبة للمصنفين المدربين على نصوص كل من المؤلفين، يمكننا استدعاء الطريقة `predict_proba` واختيار النتيجة من الاحتمالات التي تم الحصول عليها باستخدام الطريقة `softmax`
# * يمكننا تدريس مصنف جديد على نصوص مؤلفين، أي تقليل المهمة إلى مخطط `one against one`. في هذه الحالة، من المعقول استخدام `roc_auc` كمقياس.
# سوف نستخدم جميع الأدوات.
# دعونا نجرب بالطريقة التالية. بالنسبة لكل نص، في مجموعة الاختبار، سنجري مباراة فاصلة بين المؤلف الحقيقي وأي نص آخر، واحدًا تلو الآخر. سنقوم بحساب `accuracy` وتحديد أسماء الملفات التي تم تعريف المؤلف فيها بشكل غير صحيح. أولاً، سنقوم بتجربة مجموعة الاختبار؛ ثم سوف نتحقق من أعمال إيلف وبيتروف.

# %%
def test_hyppo(recognizer, PATH='../test_corpus/', softmax=False):
    files = listdir(PATH)
    true = 0; all = 0
    print('________________________________________________')    
    for file in files:
        real_author = file.split('_')[0]
        if real_author not in recognizer.authors:
            continue
        another_authors = recognizer.authors.copy()
        another_authors.remove(real_author)
        for author in another_authors:     
            
            all += 1
            pred =  recognizer.hypothesis_test(path.join(PATH, file), author, real_author, softmax=softmax)
            #pdb.set_trace()
            pred_author = pred[pred == pred.max()].index[0]
            if real_author == pred_author:
                true +=1
            else:
                print(f'{file} - {author}')   
    if PATH != '../IlfPetrov/':
        print(f'Accuracy {100 * true / all:.2f}% in {all} experiments')

# %% [markdown]
# #### SVM مع نواة *خطية*

# %%
params = {'random_state':42, 'kernel':'linear'}
recognizer.fit(model=SVC, params=params, mode='oao', train_size=train_size, random_state=42)
test_hyppo(recognizer=recognizer)
test_hyppo(recognizer=recognizer, PATH=ilf_petrov)
print()
print('12 Chairs')
print(recognizer.hypothesis_test('../IlfPetrov/IlfPetrov_12chairs_string.txt', 'IlfPetrov', 'Bulgakov'), end='\n\n')
print('The Golden Calf')
print(recognizer.hypothesis_test('../IlfPetrov/IlfPetrov_золотой_теленок_string.txt', 'IlfPetrov', 'Bulgakov'))

# %% [markdown]
# #### SVM مع نواة *rbf*

# %%
params = {'random_state':42, 'kernel':'rbf'}
recognizer.fit(model=SVC, params=params, mode='oao', train_size=train_size, random_state=42)
test_hyppo(recognizer=recognizer)
test_hyppo(recognizer=recognizer, PATH=ilf_petrov)
print()
print('12 Chairs')
print(recognizer.hypothesis_test('../IlfPetrov/IlfPetrov_12chairs_string.txt', 'IlfPetrov', 'Bulgakov'), end='\n\n')
print('The Golden Calf')
print(recognizer.hypothesis_test('../IlfPetrov/IlfPetrov_золотой_теленок_string.txt', 'IlfPetrov', 'Bulgakov'))

# %% [markdown]
# #### الانحدار اللوجستي مثل *واحد مرة أخرى*

# %%
params={'random_state':42, 'class_weight':'balanced', 'solver':'liblinear'}
recognizer.fit(model=LogisticRegression, params=params, mode='oaa', train_size=train_size, random_state=42)
test_hyppo(recognizer=recognizer)
test_hyppo(recognizer=recognizer, PATH=ilf_petrov)
print()
print("'12 Chairs'")
print(recognizer.hypothesis_test('../IlfPetrov/IlfPetrov_12chairs_string.txt', 'IlfPetrov', 'Bulgakov'), end='\n\n')
print("'The Golden Calf'")
print(recognizer.hypothesis_test('../IlfPetrov/IlfPetrov_золотой_теленок_string.txt', 'IlfPetrov', 'Bulgakov'))

# %% [markdown]
# #### الانحدار اللوجستي مع *softmax*

# %%
params={'random_state':42, 'class_weight':'balanced', 'solver':'liblinear'}
recognizer.fit(model=LogisticRegression, params=params, mode='oaa', train_size=train_size, random_state=42)
test_hyppo(recognizer=recognizer, softmax=True)
test_hyppo(recognizer=recognizer, PATH=ilf_petrov, softmax=True)
print()
print("'12 Chairs'")
print(recognizer.hypothesis_test('../IlfPetrov/IlfPetrov_12chairs_string.txt', 'IlfPetrov', 'Bulgakov'), end='\n\n')
print("'The Golden Calf'")
print(recognizer.hypothesis_test('../IlfPetrov/IlfPetrov_золотой_теленок_string.txt', 'IlfPetrov', 'Bulgakov'))

# %% [markdown]
# لقد حصلنا على أفضل دقة باستخدام SVM مع النواة الخطية والانحدار اللوجستي *واحد مقابل واحد*. في الإصدار الأول، تتعرف الخوارزمية على بولجاكوف باعتباره مؤلف كتاب "الكراسي الاثني عشر" ولكن مع حد أدنى من الهامش، وفي الإصدار الثاني حصلنا على التعادل - 05: 0.5 لكلا العملين.

# %% [markdown]
# وأود أيضًا أن أذكر أن:
# 1. في معظم التجارب، تم التعرف على ميخائيل بولجاكوف باعتباره المؤلف الحقيقي لكتاب "جزيرة إريندورف" لفالنتين كاتاييف. تمت كتابة القصة في عام 1924. ونحن نعلم أنه في ذلك الوقت، كان كاتاييف وبولجاكوف يعملان معًا في صحيفة "جودوك" في موسكو. تم نشر أعمال بولجاكوف قليلاً، حتى يتمكن من كتابة القصة ومطالبة كاتاييف بنشرها باسمه مقابل رسوم (لكن الأمر ليس كذلك بالضبط).
# 2. يواجه العديد من المصنفين صعوبات في التعرف على مؤلف رواية "الرجال الثلاثة السمان" وكأن أولشا لم يكتبها. ربما تم تحرير الرواية في منتصف القرن العشرين. ولهذا السبب، نستبعد رواية ليف كاسيل «الكتاب الأسود وشوامبرانيا» من مبنى التدريب عندما نخمن أن الرواية خضعت لمراجعة كبيرة في الخمسينيات (ولكن الأمر ليس كذلك تمامًا).

# %% [markdown]
# ### <center> الاستنتاجات </center>
#
# في هذا المشروع، تناولنا إحدى طرق التعرف على مؤلفي الكتب، استنادًا إلى حساب الأشكال الثلاثية الأكثر ظهورًا. حاولنا التعرف على مؤلفي روايتي "الكراسي الاثني عشر" و"العجل الذهبي". بناءً على نتائج المشروع يمكننا أن نستنتج ما يلي:1. تظهر الطريقة المقترحة نتائج جيدة في التعرف على المؤلفين، ولكنها تعتمد بشدة على المعلمات، مثل عدد الأشكال الثلاثية المستخدمة، وطول السلاسل الفرعية التي يتم تحليلها. مع تغييرات صغيرة في المعلمات، يمكن أن تختلف النتائج. علاوة على ذلك، وعلى الرغم من أن الصورة العامة سوف تتغير قليلاً، إلا أن النتائج قد تكون معاكسة جذرياً بالنسبة للقضايا الفردية.
# 2. تنطبق هذه الطريقة على النصوص الكبيرة فقط. قمنا بتحليل السلاسل التي يبلغ طولها 20000 حرف. بالنسبة للنصوص الصغيرة، هذه الطريقة غير مناسبة.
# 3. استخدمنا ثلاث خوارزميات، الانحدار اللوجستي، ونوعين من SVM، مع النواة الخطية وRBF. تم الحصول على أفضل النتائج باستخدام الانحدار اللوجستي؛ الأسوأ كان بالنسبة لـ SVM rbf kernel.
# 4. لا يمكن التعرف بشكل لا لبس فيه على مؤلف روايتي "الكراسي الاثني عشر" و"العجل الذهبي"، ولكن بالنسبة لنا، يبدو أن فرضية بولجاكوف معقولة. هناك حاجة إلى مزيد من البحث في هذا المجال. ربما، فإن استخدام هياكل التسلسلات الهرمية الأعلى (أشكال الكلمات، الطبقات النحوية، الهياكل النحوية) سيعطي نتائج أكثر موثوقية.

# %% [markdown]
# ### <center>المراجع</center>1. إيرينا أملينسكي "12 شارعًا من ميخائيلا بولجاكوفا"، برلين، كيرشنر-فيرلاغ، 2013
# 2. دميتري جالكوفسكي <a href="@@KEEP_00029@@>"هذا المطلوب يعرف ميخائيل بولجاكوف"</a>
# 3. [أ.س. رومانوف "طريقة تحديد النص التلقائي للأداة الأساسية للناقلات"](https://docplayer.ru/29386403-Metodika-identifikacii-avtora-teksta-na-osnove-apparata-opornyh-vektorov.html)
# 4. [رومانوف أ. ج. ""التعرف على النص باستخدام جهاز ناقل الحركة في حالة وجود بديلين محتملين"](http://www.dialog-21.ru/media/1617/67.pdf)
# 5. ميخائيل كوبوتيف "الدخول في عالم اللغة"، براغ، شركة أنيميديا، 2014
# 6. تشين س.ف. دراسة تجريبية لتقنيات التجانس لنمذجة اللغة S.F. تشين، ج. جودمان كمبيوتر الكلام واللغة. – 1999. – المجلد. 13، رقم 4.
# 7. В.П.Фоменко, Т.Г.Фоменко ["نصوص أدبية روسية مبتكرة"](http://chronologia.org/seven2_2/add3.html)
