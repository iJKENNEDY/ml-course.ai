# %% [markdown]
# # ماذا يوجد تحت غطاء محرك السيارة الخاص بك؟
# هذا البرنامج التعليمي لا يتعلق بأساليب ونماذج الرياضيات.
# سأركز على البيئة لتعلم ML
# عملية التعلم هي وسيلة صعبة. وهناك العديد من العوامل التي كان لها تأثير على هذه العملية. غالبًا ما يكون مزاجك منطقيًا.<br/>
# وفي برامج الدراسة الذاتية، يعتبر التحفيز والمواقف من أصدقائك الأساسيين.
# ## لنبدأ.
# الآن سيكون هناك القليل من الفلسفة، وأطلب منك عدم الانتقال إلى **الجزء الفني**. سيكون هناك بعض الأفكار الكبيرة.
# الأشخاص الذين حضروا البرامج التعليمية في هذه الجلسة هم بالتأكيد أشخاص أقوياء ويعرفون الكثير.
# أعتقد أن هذا الدفتر (ربما مقالًا) سيكون أكثر فائدة لمرضى الجلسة القادمة. لقد لعبت الكثير من الدروس من الدورة السابقة دورًا مهمًا بالنسبة لي.
# لماذا أعتقد أن هذه الدورة هي الأفضل على الإطلاق؟ شيئين. أولا - العرض الممتاز للمادة . والثاني هو - آلية التحفيز. إنه رائع.
# **المسابقات**. العملية التنافسية تؤدي إلى اتخاذ أفضل القرارات وتحفز المشاركين. لذلك كان معي.ولكن، ماذا لو لم تعد ميزة الانحدار الجديدة تتبادر إلى الذهن؟
# <br/>
# <br/>
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/6otSIv1XOfpfaJymvYiDREr2tqLPw6guKfjfrzTr1BYKczGt2tm_Exwc-ViDR6jIJ0PucB4KQtpb=s350)
# <br/>
# <br/>
# وقد أدت المنافسة المتوسطة إلى القضاء على النواة على Google Colab لعدة مرات. جهاز الكمبيوتر الخاص بك يصبح لبنة؟
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/f0VOcxIDsybtodLmev6I1c3Km7HzyTG_3KaegdvqocapJLitm8iD2l3NznlJeSh-SubSq8nzPOvY=s250)
# <br/>
# <br/>
# وفي الوقت نفسه، ينجح شاب (أو فتاة) من الطرف الآخر من العالم في الوصول إلى خط الأساس ويصل إلى أعلى 1%. فتعالوا بقطعة من الحديد! دعونا نحاول ضبط بعض معلمات النموذج!
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/lukZkLkxJJjhBgW1W8HKBclDsc7EH5Yyp_MYRcIqlIojtZz3r5W02elHv0oB3T63v4vRdyiH_oN1=s500)
# إعادة التشغيل. أوه...سأذهب إلى النوم، غدًا سأقوم بتحسين:
#  - [ ] الكود
#  - [ ] الحساب
#  - [ ] الأجهزة
#  - [ ] الدماغ
# *ننسى*
#  - جرب أسلوبًا جديدًا (*hello n-gramm in td-idf*).
#  - تعرف على ما إذا كان سيتم تحقيق مكاسب في التحقق المتبادل من خلال إضافة الوقت الذي تقضيه أليس على YouTube.
#
#  يستغرق كلاهما وقتًا، والذي يعتمد بشكل مباشر (دائمًا تقريبًا) على الجهاز الذي تقوم بتشغيل النموذج الخاص بك.
# إذا اكتشفت أيضًا عالم التعزيزات المتدرجة
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/aYgmP4JCjd4TV7f0Jp4QVvSjiHvFSmbYMEvUhxoGYlXxtcdVZomdQzkTEJ4OQL6lDQfhkzk_UbGb=s300)
# ## الخيارات
# لدي جهاز كمبيوتر محمول قديم مزود بمعالج i5 وذاكرة وصول عشوائي سعتها 4 جيجابايت. عقلي أسرع منه في بعض الأحيان.
# لقد انزعجت من توقفه الطويل عن تدريب النموذج أو خطأ الذاكرة في تحدي التغلب على خطوط الأساس في هذه الدورة.
# ### ما يمكنني فعله:
#
#  1. **الصيغة الأولى:**
# 	شراء جهاز جديد. ما لدينا هناك، أوه نعم:
#
#  -I7-8700k 400\$
#  - 1080TI 1000\$
#  - 64 جيجا رام = في حوالي 500\$
#  - اللوحة الأم
#  - قرص ssd وما إلى ذلك ...
# 		توقف توقف، أنا فقط أتعلم...
# 2. **الخيار 2:**تحسين الكود أو الحوسبة. اختيار جيد، الأساس الصحيح للمستقبل.
#     لكن المواعيد النهائية للعمل والدراسة والأسرة... أين تجد الوقت لكل هذا؟
# 	بالإضافة إلى ذلك، أقضي الكثير من الوقت في النقل (المترو والقطار والنقل) وأريد قضاء وقتي بفعالية.
#     بالإضافة إلى ذلك، غالبًا ما تأتي الأفكار الجيدة في أماكن غير متوقعة وأريد اختبارها على الفور.
# <br/>
# <br/>
# 3. ** مما سبق، يظهر خيار ثالث ** - خذ جهازًا قويًا في السحابة. وقم بالاتصال به من أي جهاز، مع وجود وحش قوي دائمًا تحت الغطاء. *"A rom dom dom" NFS Underground OST.*
# ## محرك حساب جوجل.
# في الواقع، هناك العديد من الشركات التي تقدم موارد للحوسبة السحابية. أحد الجوانب المهمة بالنسبة لي هو أن الخدمة يجب أن تكون مجانية ومرنة واكتمال الفرص المقدمة. ولذلك اخترت جوجل.
# في الحسابات الخفيفة، يمكنك العمل مع Colab أو Kaggle Kernels. ولكن هناك حدود للذاكرة.
# <br/>
# <br/>
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/lukZkLkxJJjhBgW1W8HKBclDsc7EH5Yyp_MYRcIqlIojtZz3r5W02elHv0oB3T63v4vRdyiH_oN1=s500)
# قد يكون هناك عدة أسباب. غالبًا ما يكون نقص موارد الحوسبة (الذاكرة). والشيء الأكثر إزعاجًا هو أن جميع الخلايا تحتاج الآن إلى إعادة التشغيل. عند حفظ الكائنات الناتجة في النص أو المخلل أنت الفائز. لكن الممارسة فقط هي التي تجعل الكمال. في بداية مسار التعلم، قد تؤدي عمليات إعادة تشغيل النواة هذه إلى الغضب في المقام الأول. ثانيا، يستغرق الكثير من الوقت.
# في الوقت الحالي سنستفيد من هدية رائعة من Google بمبلغ *300\$.*
# #الجزء الفني
# ما تحتاجه للبدء:1. **تسجيل الحساب** *(من المثير للاهتمام، كم منكم أيها القراء الأعزاء لم يمتلكه بعد؟)*
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/VWR3LnP9UukK56ozWZ1rhS9MJ2-z5GTF6wnMaL5B97uVa3W11llt1dSmkPCipRYOfC45Bhh8DcMO=s500)
# لا يوجد شيء معقد، كل شيء قياسي. تأكيد البريد والهاتف. حدد رقم هاتف حقيقي سيتم استخدامه لتأكيد الفواتير.
#  2. ** هيا بنا ** [https://console.cloud.google.com/freetrial/signup](https://console.cloud.google.com/freetrial/signup)
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/e3HA4Egms73EWxxy1t4aDeK1glUFxHvH6yoWQre7Zv73CwNYtewec2EKIVUpto3FD-vBRrf5GhhS=s500)
# سترى أنهم يعطوننا 300\$ and 12 months. I note that my account decreased by only 10.53 \$ خلال هذه الدورة من البروفيسور يوركو وزملائه.
# يمكنك تأكيد البطاقة بأمان (سيقوم النظام بحظر 1 دولار عليها لمدة ساعة واحدة في المتوسط)
# 3. **انتقل إلى** [https://console.cloud.google.com/compute/](https://console.cloud.google.com/compute/)
# - #### إنشاء مشروع.
# - #### الجزء الأكثر إثارة للاهتمام يبدأ الآن.
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/UZ3wbfzLCnlK4En16E2vniF_vb5VoTXY01iP6CM4LwOr3vpYB_GSypTls9wUD0wPO74qQniMtM3d=s500)
# افتح متجر الأجهزة (أو الإيجار).
# <br/>
# <br/>
# *** ملء السلطة؟!***
# - #### لنقم بإنشاء مثيل جديد!
# خذ أكثر قوة. 8 وحدة معالجة مركزية و52 جيجابايت من ذاكرة الوصول العشوائي.
# 	أعتقد أنه لا فائدة من أن يأخذ مثيلي قوة وحدة معالجة الرسومات. لأن الشبكات العصبية في هذه الدورة لا تعتبر. وإذا كنت تريد - يوجد GPU مجاني في Google Colab. لكن بعض المكتبات المعززة تدعم الآن وحدة معالجة الرسومات. لذلك، راقب التغييرات عن كثب واختر معلمات المثيل بناءً على احتياجاتك.
# *شعرت بالحاجة الملحة إلى موارد إضافية عندما بدأت باستخدام XGBOOST، تشير الوثائق الخاصة به إلى وجود دعم لوحدة معالجة الرسومات، ولكن عندما بدأت باستخدام وحدات معالجة الرسومات Colab، بدأت في قتل النواة.*
# - #### تغيير قرص التمهيد إلى Ubuntu 16.04. ولكن هذا هو لاختيارك
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/O81SHvcQlhYKQcx8K4iXBLgvvrUWHkUMY-uY3NJDVETDTnN1YpApo8twOlwQs_0oRoDaakFYL4mT "500")
# - #### تكوين جدار الحماية وإزالة مربع الاختيار من علامة التبويب "الأقراص".
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/qkhUA7e4r1nZl-l0HPfF7vWiHFURXDbZv9on2OYAgrdRJ-iqRt6eMFtbrcLAQL8uMeVVEHUKc8WQ=s500)
# - #### اضغط على زر الإنشاء - وفويلا - لدينا جهاز قوي للركوب معه.* ولكن انتظر لحظة. ستحتاج إلى تعيين عنوان IP ثابت:*
# - #### انتقل إلى شبكة VPC - عناوين IP الخارجية. تغييره إلى ثابت.
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/pzlYFHp6iLSXuYDQPsMWSSOGZZTFSJ9_eMp_A909y4su_6NxosZsdE5KKrJ28LDMnfCeAu3RdUza=s500)
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/GeaNbBqVNYrNBPZZ4Gcsf2PLc-akMh73q4jHS5MJGr3qWXoTzSyKKWF_WFn5LtS83BG3fXZ4pR6a=s500)
# - #### حسنًا. الخطوة التالية - ضبط إعدادات جدار الحماية - قواعد جدار الحماية. إضافة واحدة جديدة.
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/SvSr2AjM_om8hQSl8lC6rK6uij-UyDG1g7NyyoGdvLqx8SspqVUnlVEPOEJYCFWOEuVc1gY3KW2m=s500)
# - #### الاتصال بالمثيل عن طريق SSH.
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/G1a5A9zVWIUs96AWPhAZRSRUQ2LWrSHBHtXSwB2sgTd021JtdHiVQeNhkxcVPr8GiHGDWKjjnf_y=s700)
# - #### لنقم بتثبيت اناكوندا
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/KIvwcfhb2h6_P93aYiAMVoVSeLDgymdXfZsLObaT4ww4WHsNwQe4qFshMGfq4PiC2X3QoWyxlp1l=s500)
# > wget http://repo.continuum.io/archive/Anaconda3-5.0.1-Linux-x86_64.sh
# >
# > باش Anaconda3-5.0.1-Linux-x86_64.sh
# اقرأ القواعد ومراجعة التثبيت وتشغيله.
# - الآن سنقوم بعمل *config*، وفتح منفذ لاتصال TCP.
#
# > دفتر jupyter - إنشاء التكوين
# >
# > نانو ~/.jupyter/jupyter_notebook_config.py
# - أضف هذه السطور. أو البحث وإلغاء التعليق الموجودة.
# > c.NotebookApp.ip = '*'
# >
# > c.NotebookApp.open_browser = خطأ
# >
# > ج.NotebookApp.port = 8000
# - غداء جوبيتر
# > دفتر Jupyter --ip=0.0.0.0
# - لرؤية الصفحة الرئيسية المعتادة لـ Jupyter - قم بتشغيل المتصفح وانتقل إلى:
# > https://"StaticIP":"Port"/?token=YOUR_TOKEN
# >
# "StaticIP" - عنوان IP خارجي على سبيل المثال
# <br/>
# "المنفذ"= 8000 (منفذ TCP الذي سمحنا به في جدار الحماية)
# <br/>
# الرمز المميز- ستراه في المحطة
# <br/>
# ## أنت في العمل.
# يمكن تثبيت جميع المكتبات الضرورية عن طريق تشغيل الأمر التالي.
# > ! نقطة تثبيت lightGBM
# دعونا نرى ما هو تحت غطاء محرك السيارة:
# > !cat /proc/cpuinfo
# >
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/Hp-b3htLYMKPr35VJoI6C68GFUYnRsRZVK_W9sLmgz0J5q6Z9FISegloXeGurfBPYfkSLig4PbdP=s700)
# هناك 8 قطع مثل هذا
# >
# > !cat /proc/meminfo
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/oxof2OB8shF9CnyvMiK4WZBj7rjskGzG9jmKk-fk4IOttMaOLdoZagYWMkE9yOC5o67JkLonyZPS=s700)
# *ليس سيئا، حان وقت الركوب*
# ## واجهة برمجة تطبيقات كاجيل
# - إنشاء دير للرمز المميز:
# > !mkdir -p ~/.kaggle
# >
# - خذ json من هنا:
# https://www.kaggle.com/"YourAccountName"/account
# ![
# ](https://lh3.googleusercontent.com/ey8NCFmjKvBy9GpyXonQT4WO7vStWdkwsd3wq1O_2hn8cHTLmrqy0xHg4y_KmArxHfrdkrofqQWf "700")- ووضعها هنا:
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/ICPiWa5AEXKAb0YJu90gd0SKZySaU4FHteI0-JRiN-a12HuG_s0kch629eNOw4DLzEdxNUDExg0M=s700)
# - انسخ إلى دليل "kaggle":
# > !cp kaggle.json ~/.kaggle/
# *الآن يمكنك تنزيل/إرسال الملفات من Kaggle. وهو سريع جداً*
#  - قم بتنزيل مجموعة بيانات المنافسة المتوسطة
# *إنشاء دير جديد للمتوسط*
# > !mkdir متوسط
#  - تغيير نظام التشغيل dir لسهولة الوصول إلى الملفات
# > استيراد نظام التشغيل
# > os.chdir('متوسط')
#  - ابدأ التنزيل
# > !kaggle مسابقات تنزيل -c ما مدى جودة مقالتك المتوسطة.
# ## الآن عن السرعة.
# نفس مجموعة البيانات، نفس الرمز. انظر إلى الوقت:
#  #### جوجل كلاود
#  ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/vrqmjVJ2WabrKmD-K6_WprvIbE1vIfJAlgMEGtAyUsVET3z0KhL6UNaMCjT85QwM0eLTbn7GKS5q=s700)
# #### جهاز الكمبيوتر المحمول الخاص بي![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/lJDUYXNlqPjfJtM6_E5JiwKadtELIapDyBQTOdP65afuWuttMHB7__otdMipKuvCdDw68LIcs3rq=s500)
# *حسنا.*
# ## جيت
# - بالمناسبة يمكنك بسهولة استنساخ مستودعاتك من جيثب.
# > !جيت استنساخ
# > [https://github.com/mikhailsergeevi4/crm.git](https://github.com/mikhailsergeevi4/crm.git)
# - الالتزام
# - ودفعهم إلى الوراء.
# > !git دفع الأصل الرئيسي
# هناك العديد من الحيل المفيدة الأخرى حول Google Cloud وColab. ولكن أعتقد أن هذا يكفي لهذه المرة
# ونتيجة لذلك، تحصل على آلة قوية لدراسة ML.
# تعلم أو اعمل أو قم بإنشاء عروض تقديمية للكمبيوتر الدفتري الخاص بك من أي جهاز.
# مبلغ 300 دولار كافي لإكمال الدورة. لقد استخدمت مثيلات في الغالب لعمليات الموارد العالية. بالنسبة للأشياء البسيطة، يوجد Google Colab (بالمناسبة، مع بطاقة فيديو مجانية)
# ** هام: لا تنس إيقاف المثيل عند الانتهاء. سوف تلتهم هذه الآلة الميزانية المخصصة بسرعة!**
# ![أدخل وصف الصورة هنا](https://lh3.googleusercontent.com/V-fUVAZDHX4PsrU_wgqgRd4mxZW9nGdbv7LpH94mi8Zg7LCf-7ikZlsf2ELoTVDDzy7JN5S9KXEm=s700)
